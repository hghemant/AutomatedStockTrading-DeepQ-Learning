# %% [markdown]
# # Deep Q- learning Agent- Stock Trading

# %% [markdown]
# ### Import- Data and Functions

# %% [markdown]
# <b>
#     We begin with inputing following variables:
#     - Stock1_name: this is first stock name, which is Google - googl.us
#     - Stock2_name: this is second stock name, which is Walmart - wm.us
#     - episode_count: This is number of episodes which agent till train on
#     - Start_balance: This is the initial starting cash, which is $ 10,000
#     - Training: This is number of records used for trading i.e. number of days on each episode of training will run
#     - Test: This is number of days on which test run will be executed
#
#  </b>

# %%
from agent.agent import Agent
from state.state import State
import pandas as pd
from functions import *
import sys

import pandas as pd

import math, random 
import numpy as np 
from datetime import datetime, timedelta

#stock_name, window_size, episode_count = sys.argv[1], int(sys.argv[2]), int(sys.argv[3])

stock_name1,stock_name2, episode_count, start_balance, training, test = 'googl.us','wm.us', 51,10000,1500,500


pd_data1=pd.read_csv('data/aapl.us.txt', sep=",", header=0)
pd_data2=pd.read_csv('data/amzn.us.txt', sep=",", header=0)

# %% [markdown]
# ### Data Pre-processing

# %% [markdown]
# In this section we will do the following:
# 1. Look at the data of google and walmart stock for checking missing data. Also convert date into right format
# 2. Make sure that both the stock data is for the same time period and same days in this time period. Remove data if necessary
# 3. Look at descriptive statistics of data- mean, median, number of records
# 4. Visualize the data to see how stock price changes with time

# %% [markdown]
# #### View google Stock data

# %%
pd_data1.head()
# Out:
#          Date     Open     High      Low    Close    Volume  OpenInt
# 0  1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030        0
# 1  1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532        0
# 2  1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199        0
# 3  1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801        0
# 4  1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062        0

# %% [markdown]
# #### View walmart Stock data

# %%
pd_data2.head()
# Out:
#          Date  Open  High   Low  Close    Volume  OpenInt
# 0  1997-05-16  1.97  1.98  1.71   1.73  14700000        0
# 1  1997-05-19  1.76  1.77  1.62   1.71   6106800        0
# 2  1997-05-20  1.73  1.75  1.64   1.64   5467200        0
# 3  1997-05-21  1.64  1.65  1.38   1.43  18853200        0
# 4  1997-05-22  1.44  1.45  1.31   1.40  11776800        0

# %% [markdown]
# #### Date in Above data is not in Dateformat, so converting date to date format

# %%
#Convert  Date to Date format
pd_data1['Date']=pd.to_datetime(pd_data1['Date'], format='%Y/%m/%d')
pd_data2['Date']=pd.to_datetime(pd_data2['Date'], format='%Y/%m/%d')

# %% [markdown]
# #### Desciptive statistics of google  and walmart data

# %% [markdown]
# google  Stock- descriptive statistics

# %%
pd_data1.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  8364.000000  8364.000000  8364.000000  8364.000000  8.364000e+03
# mean     22.284350    22.495867    22.054244    22.281018  1.066416e+08
# std      37.763402    38.057733    37.447432    37.764469  9.935187e+07
# min       0.233050     0.235640     0.230510     0.230510  0.000000e+00
# 25%       1.137100     1.164200     1.112800     1.137100  4.384365e+07
# 50%       1.632800     1.663400     1.600600     1.628250  7.481383e+07
# 75%      23.739000    23.930500    23.335750    23.694500  1.320534e+08
# max     175.110000   175.610000   174.270000   175.610000  2.069770e+09
#
#        OpenInt
# count   8364.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# walmart Stock- descriptve statistics

# %%
pd_data2.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  5153.000000  5153.000000  5153.000000  5153.000000  5.153000e+03
# mean    181.747357   183.880652   179.466684   181.769343  7.837325e+06
# std     239.611052   241.226109   237.638139   239.548391  7.594745e+06
# min       1.410000     1.450000     1.310000     1.400000  0.000000e+00
# 25%      35.500000    36.130000    35.000000    35.550000  3.779449e+06
# 50%      70.900000    72.750000    69.020000    70.700000  5.902992e+06
# 75%     242.850000   245.770000   240.670000   243.880000  8.888949e+06
# max    1126.100000  1135.540000  1124.060000  1132.880000  1.043288e+08
#
#        OpenInt
# count   5153.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# #### Drop Data that is not in both stock data- some days data is missing in google  and some in walmart

# %% [markdown]
# I have made another program to look at data that is common in both stocks and to find out if there are any anamolies. Using this program I found out some data that is missing in either google  or walmart stock data

# %%
pd_data2['Date'][0]
# Out:
# Timestamp('1997-05-16 00:00:00')

# %%
pd_data1['Date'][0]
# Out:
# Timestamp('1984-09-07 00:00:00')

# %%
if (pd_data1['Date'][0]>pd_data2['Date'][0]): 
    #print("Date1 is older than Date2")
    pd_data1=pd_data1[pd_data1.Date>=pd_data2['Date'][0]]
    pd_data1=pd_data1.reset_index(drop=True)
else:
    #print("Date2>Date1")
    pd_data2=pd_data2[pd_data2.Date>=pd_data1['Date'][0]]
    pd_data2=pd_data2.reset_index(drop=True)
    #print("Date2>Date1  and date2 is" + str(pd_data2['Date'][0]) +" Date 1 is : "+ str(pd_data1['Date'][0]))

# %%
pd_data2.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  5153.000000  5153.000000  5153.000000  5153.000000  5.153000e+03
# mean    181.747357   183.880652   179.466684   181.769343  7.837325e+06
# std     239.611052   241.226109   237.638139   239.548391  7.594745e+06
# min       1.410000     1.450000     1.310000     1.400000  0.000000e+00
# 25%      35.500000    36.130000    35.000000    35.550000  3.779449e+06
# 50%      70.900000    72.750000    69.020000    70.700000  5.902992e+06
# 75%     242.850000   245.770000   240.670000   243.880000  8.888949e+06
# max    1126.100000  1135.540000  1124.060000  1132.880000  1.043288e+08
#
#        OpenInt
# count   5153.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
# Pre -Processing the Datasheet ...Drop Datafor  some days data is missing in google  and some in walmart
import datetime
#timestamp = data1_date[10]
#print(timestamp.strftime('%Y-%m-%d'))
list1= pd_data1['Date']
list2= pd_data2['Date']
diff_pd1_data = list(set(list1) - set(list2))
diff_pd2_data = list(set(list2) - set(list1))
#x11=x[0].strftime('%Y-%m-%d 00:00:00')
#p=datetime.datetime.strptime(x11, "%Y-%m-%d 00:00:00")
#print(p)
for k in range(len(diff_pd1_data)):
    pd1_dat_format=diff_pd1_data[k].strftime('%Y-%m-%d 00:00:00')
    date_format_pd1=datetime.datetime.strptime(pd1_dat_format, "%Y-%m-%d 00:00:00")
    for i, j in enumerate(list1):
        if j == date_format_pd1:
            #print(i)
            pd_data1=pd_data1.drop([i])            
pd_data1=pd_data1.reset_index(drop=True)

for k in range(len(diff_pd2_data)):
    pd2_dat_format=diff_pd2_data[k].strftime('%Y-%m-%d 00:00:00')
    date_format_pd2=datetime.datetime.strptime(pd2_dat_format, "%Y-%m-%d 00:00:00")
    for M, N in enumerate(list2):
        if N == date_format_pd2:
            #print(M)
            pd_data2=pd_data2.drop([M])
            
pd_data2=pd_data2.reset_index(drop=True)

# %%
pd_data1.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  5151.000000  5151.000000  5151.000000  5151.000000  5.151000e+03
# mean     35.484689    35.816124    35.123519    35.479585  1.367661e+08
# std      43.150378    43.473086    42.805762    43.153299  1.119530e+08
# min       0.412350     0.423880     0.408530     0.413660  0.000000e+00
# 25%       1.518700     1.552100     1.488200     1.521300  6.327315e+07
# 50%      12.362000    12.710000    12.060000    12.403000  1.075093e+08
# 75%      64.097000    64.834000    63.631500    64.308500  1.764941e+08
# max     175.110000   175.610000   174.270000   175.610000  2.069770e+09
#
#        OpenInt
# count   5151.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
pd_data2.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  5151.000000  5151.000000  5151.000000  5151.000000  5.151000e+03
# mean    181.812687   183.946772   179.531361   181.834821  7.835138e+06
# std     239.634626   241.249596   237.661600   239.571842  7.594587e+06
# min       1.410000     1.450000     1.310000     1.400000  0.000000e+00
# 25%      35.500000    36.230000    35.010000    35.580000  3.777334e+06
# 50%      70.940000    72.810000    69.020000    70.730000  5.901100e+06
# 75%     243.035000   246.240000   241.015000   243.900000  8.888874e+06
# max    1126.100000  1135.540000  1124.060000  1132.880000  1.043288e+08
#
#        OpenInt
# count   5151.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# ### Data Visualization

# %%
# Google Stock Plot
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %matplotlib inline

x1 = np.array(pd_data1['Date'])
y1 = pd_data1['Open']
y12= pd_data1['Volume']

plt.title("google Stock Performance Over years")
plt.xlabel("Year")
plt.ylabel("Price in $")



plt.plot(x1,y1)


ax2 = plt.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:green'
ax2.set_ylabel('volume', color=color)  # we already handled the x-label with ax1
ax2.plot(x1, y12, color=color)
ax2.tick_params(axis='y', labelcolor=color)



plt.show()

# %%
# Walmart Stock Plot
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %matplotlib inline

x2 = np.array(pd_data2['Date'])
y2 = pd_data2['Open']
y22= pd_data2['Volume']


plt.title("walmart Stock Performance Over years")
plt.xlabel("Year")
plt.ylabel("Price in $")

plt.plot(x2,y2)


ax2 = plt.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:green'
ax2.set_ylabel('volume', color=color)  # we already handled the x-label with ax1
ax2.plot(x2, y22, color=color)
ax2.tick_params(axis='y', labelcolor=color)




plt.show()

# %% [markdown]
# ### Divide Training and test data

# %% [markdown]
# Next step is to divide data into training and test set. This has to be done in a chronological order. So, data is divided into:
# - training set from days 0 to days 'training'
# - test set: from days 'training' to day 'training+ test'

# %%
#Training Data
pd_data1_train=pd_data1[0:training]
pd_data2_train=pd_data2[0:training]

# %%
#Test Data
pd_data1_test=pd_data1[training:training+test]
pd_data2_test=pd_data2[training:training+test]

# %%
vol1_train=getStockVolVec(stock_name1)
vol2_train=getStockVolVec(stock_name2)

# %%
#Initialize state and set benchmarking model



total_Prof=[]
done=False


batch_size = 64

#Benchmark Model
#In this model, we would divide 


#Initialize state and set benchmarking model


#print(df_data1)
total_Prof=[]
done=False

Act_datasize = training
batch_size = 64

#Benchmark Model

data1_train=pd_data1_train['Open']
data2_train=pd_data2_train['Open']

data1_date=pd_data1_train['Date']

Act_Bench_Stock1_Bal=int(np.floor((start_balance/4)/data1_train[0]))
Act_Bench_Stock2_Bal=int(np.floor((start_balance/4)/data2_train[0]))
Act_Bench_Open_cash=start_balance/2




### Program to calculate benchmark profit


#sell 10% of stock in 10 intervals

interval=int(Act_datasize/10)
Total_Stock1_Amount= 0
Total_Stock2_Amount= 0
stocks2Value = 0
stocks1Value = 0

Act_stocks1=np.floor(Act_Bench_Stock1_Bal /10)
Act_stocks2=np.floor(Act_Bench_Stock2_Bal /10)
#print(str(Act_stocks1))
#print(str(Act_stocks2))

remaining_stock1=Act_Bench_Stock1_Bal
remaining_stock2=Act_Bench_Stock2_Bal
ttl=0

Benchmark_Port_Value=[]


for j in range (interval,Act_datasize+1,interval):
        #print("closing prices : " + str(data1_train[j-1]) )
        Price_closing_Stock1=data1_train[j-1]
        Price_closing_Stock2=data2_train[j-1]
        
        date_stock1=data1_date[j-1].strftime('%Y-%m-%d')
        #print(date_stock1)
                
        stocks1Value= Act_stocks1 * Price_closing_Stock1
        stocks2Value= Act_stocks2 * Price_closing_Stock2
        remaining_stock1=remaining_stock1-Act_stocks1
        remaining_stock2=remaining_stock2-Act_stocks2
        #print("J is:"+ str(j))
        
        
        
        Stock1_Port_value=remaining_stock1*Price_closing_Stock1
        Stock2_Port_value=remaining_stock2*Price_closing_Stock2
        Act_Bench_Open_cash=Act_Bench_Open_cash+stocks1Value+stocks2Value #Adding 10% sold value into open cash
        
        Total_Portfolio_value=Act_Bench_Open_cash+Stock1_Port_value+Stock2_Port_value
        Benchmark_Port_Value.append([date_stock1,Total_Portfolio_value])
        



#print ("total_Test_Benchmark_amount : " +  str(Total_Portfolio_value))

Training_Benchmark_Portfolio_Value= Total_Portfolio_value




print("Benchmark_Profit is  " + str(Training_Benchmark_Portfolio_Value) +"with google Stocks:  " + str(remaining_stock1) + 
      " and walmart stocks:  "+ str(remaining_stock2) )


#Define arrays to store per episode values 
total_Prof=[]
total_stock1bal=[]
total_stock2bal=[]
total_open_cash=[]
total_port_value=[]
total_days_played=[]
# Out:
# Benchmark_Profit is  52655.37275with google Stocks:  6.0 and walmart stocks:  9.0

# %% [markdown]
# # Training Run

# %%
#Training run

import csv


for e in range(episode_count + 1):
    print("..........")
    print("Episode " + str(e) + "/" + str(episode_count))
    
    Bal_stock1=int(np.floor((start_balance/4)/data1_train[0]))
    Bal_stock2=int(np.floor((start_balance/4)/data2_train[0]))
    open_cash=start_balance/2
    
    datasize=training
    done=False
    total_profit = 0
    reward = 0
    
    #Initialize Agent
    agent = Agent(8)
    agent.inventory1 =[]
    agent.inventory2 =[]
    for i in range(Bal_stock1):
        agent.inventory1.append(data1_train[0])
    for i in range(Bal_stock2):
        agent.inventory2.append(data2_train[0]) 
    
    
    #Timestep delta to make sure that with time reward increases for taking action
    #timestep_delta=0
    
    #Running episode over all days in the datasize
    for t in range(datasize):
        #print("..........")
        #print(pd_data1_train.iloc[t,0])
        state_class_obj= State(data1_train, data2_train, Bal_stock1, Bal_stock2, open_cash,t)
        state_array_obj=state_class_obj.getState()
        action = agent.act(state_array_obj)
         
                   
        change_percent_stock1=(state_class_obj.Stock1Price-state_class_obj.fiveday_stock1)/state_class_obj.fiveday_stock1*100
        change_percent_stock2=(state_class_obj.Stock2Price-state_class_obj.fiveday_stock2)/state_class_obj.fiveday_stock2*100
        
        #print("change_percent_stock1:  "+str(change_percent_stock1))
        #print("change_percent_stock2:  "+str(change_percent_stock2))
        
        
        if action == 0:  #buy stock 1
            if state_class_obj.Stock1Price > state_class_obj.open_cash:
                '''
                print("Buy stock 1 when it did not have cash, so bankrupt, end of episode")
                reward=-reward_timedelta*10
                done = True
                '''
                #If agent is trying to buy when it has no cash but has stock1 and stock2 balance then, 
                #it should pick from other actions
                #if (state_class_obj.Stock1Blnc>1) and  (state_class_obj.Stock2Blnc>1):
                 #   action=random.sample([1, 2, 4, 5, 6],  1)  # Choose 1 elements from sell actions
                #else:    
                #print("Bankrupt")
                reward=-200000
                done = True
                #end episode
                     
            else:
                #print("In Buy stock 1")
                agent.inventory1.append(data1_train[t])
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=state_class_obj.open_cash-state_class_obj.Stock1Price #Here we are buying 1 stock
                
                #needs to be reviewed
                
                if(state_class_obj.open_cash<500):
                    reward=-100000
                elif (abs(change_percent_stock1)<=2):
                    reward=-10000
                else:  
                    reward=-change_percent_stock1*100
                

               
                
        if action == 1:  #sell stock 1
            if state_class_obj.Stock1Blnc <1 :
               # print("sold stock 2 when it did not have stock 2, so bankrupt, end of episode")
                reward=-200000
                done = True
                #end episode
            else:
                #print("In sell stock 1")
                bought_price1=agent.inventory1.pop(0)
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=state_class_obj.open_cash+state_class_obj.Stock1Price #State[0] is the price of stock 1. Here we are buying 1 stoc
          
                if(state_class_obj.Stock1Blnc<10):
                    reward=-100000
                elif (abs(change_percent_stock1)<=2):
                    reward=-10000
                else:
                    reward=change_percent_stock1*100 #State[0] is the price of stock 1. Here we are buying 1 stock
                
                #total_profit += data1_train[t] - bought_price1
            #print("reward for sell stock1 " + str(reward))
                
        


        
        if action == 2:             # Do nothing action    
                if (abs(change_percent_stock1)<=2) and (abs(change_percent_stock2)<=2):
                    reward=10000
                elif (state_class_obj.open_cash<0.1*start_balance):
                    reward=1000000
                elif (abs(change_percent_stock1)<=2) or (abs(change_percent_stock2)<=2):
                    reward=1000
                else:
                    reward=-100000
                
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=open_cash
               # print("Do nothing")
        
        
        if action == 3:  #buy stock 2
            if state_class_obj.Stock2Price > state_class_obj.open_cash:
                '''
                print("Buy stock 2 when it did not have cash, so bankrupt, end of episode")
                reward=-reward_timedelta*10
                done = True
                
                '''
                #If agent is trying to buy when it has no cash but has stock1 and stock2 balance then, 
                #it should pick from other actions
                #if (state_class_obj.Stock1Blnc>1) and  (state_class_obj.Stock2Blnc>1):
                 #   action=random.sample([1, 2, 4, 5, 6],  1)  # Choose 1 elements from sell actions
                #else:    
                #print("Bankrupt")
                reward=-200000
                done = True
                     #end episode   
            else:
                #print("In Buy stock 2")
                agent.inventory2.append(data2_train[t])
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=state_class_obj.open_cash-state_class_obj.Stock2Price
                
                if(state_class_obj.open_cash<5000):
                    reward=-100000
                elif (abs(change_percent_stock2)<=2):
                    reward=-10000
                else:
                    reward=-change_percent_stock2*100
 
        
        if action == 4:  #sell stock 2
            if state_class_obj.Stock2Blnc <1 :
                    #print("sold stock 2 when it did not have stock 2, so bankrupt, end of episode")
                    reward=-200000
                    done = True
                #end episode
            else:
                #print("In sell stock 2")
                bought_price2=agent.inventory2.pop(0)
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=state_class_obj.open_cash+state_class_obj.Stock2Price
    
              
                if(state_class_obj.Stock2Blnc<10):
                    reward=-100000
                elif (abs(change_percent_stock2)<=2):
                    reward=-10000
                else:
                    reward=change_percent_stock2*100 
                
                
                total_profit += state_class_obj.Stock2Price - bought_price2

               # print("reward for selling stock2: " + str(reward))
            
        
        
        #print("reward:  "+str(reward))
        #if done!= False:done = True if t == datasize
        if t == datasize-1:
            #print("t==datasize")
            done=True
            next_state_class_obj=State(data1_train, data2_train, Bal_stock1_t1, Bal_stock2_t1, open_cash_t1,t)
            next_state_array_obj=next_state_class_obj.getState()
        else:
            next_state_class_obj=State(data1_train, data2_train, Bal_stock1_t1, Bal_stock2_t1, open_cash_t1,t+1)
            next_state_array_obj=next_state_class_obj.getState()
            
        agent.memory.append((state_array_obj, action, reward, next_state_array_obj, done))
        #print("Action is "+str(action)+" reward is" + str(reward))
         
        Bal_stock1=Bal_stock1_t1
        Bal_stock2= Bal_stock2_t1
        open_cash=open_cash_t1
        
        
      #  print("total_profit on day basis " + str(total_profit) +"on day"+str(t) + "stock 1 number: " + 
        #      str(len(agent.inventory1))+"/"+str(next_state_class_obj.Stock1Blnc)+" stock2 number:"+
         #         str(len(agent.inventory2)) +"/"+str(next_state_class_obj.Stock2Blnc)+
          #        "open cash: "+str(next_state_class_obj.open_cash))
        
       # print("doneAction" + str(done))
       # print("--------------------------------") 
       
        
        
        if done==True:
            #print("--------------------------------")
           # print("Total Profit: " + formatPrice(total_profit))
           # print("Total No. of days played: " + str(t)+ "  out of overall days:  " + str(datasize))
           # print("Total portfolio value: " + str(next_state_class_obj.portfolio_value)+ 
             #     "  stock 1 number: " + str(len(agent.inventory1))
            #      +"  stock 2 number: "+str(len(agent.inventory2))+"  open cash"+str(next_state_class_obj.open_cash))

            total_Prof.append(total_profit)
            total_stock1bal.append(len(agent.inventory1))
            total_stock2bal.append(len(agent.inventory2))
            total_open_cash.append(state_class_obj.open_cash)
            total_port_value.append(state_class_obj.portfolio_value)
            total_days_played.append(t)


            print("--------------------------------")
            state_class_obj.reset()
            break
           
          

        if len(agent.memory) > batch_size:
            agent.expReplay(batch_size)


    if e % 10 == 0:
        agent.model.save("models/model_ep" + str(e))
# Out:
# ..........
# Episode 0/51
# --------------------------------
# ..........
# Episode 1/51
# --------------------------------
# ..........
# Episode 2/51
# --------------------------------
# ..........
# Episode 3/51
# --------------------------------
# ..........
# Episode 4/51
# --------------------------------
# ..........
# Episode 5/51
# --------------------------------
# ..........
# Episode 6/51
# --------------------------------
# ..........
# Episode 7/51
# --------------------------------
# ..........
# Episode 8/51
# --------------------------------
# ..........
# Episode 9/51
# --------------------------------
# ..........
# Episode 10/51
# --------------------------------
# ..........
# Episode 11/51
# --------------------------------
# ..........
# Episode 12/51
# --------------------------------
# ..........
# Episode 13/51
# --------------------------------
# ..........
# Episode 14/51
# --------------------------------
# ..........
# Episode 15/51
# --------------------------------
# ..........
# Episode 16/51
# --------------------------------
# ..........
# Episode 17/51
# --------------------------------
# ..........
# Episode 18/51
# --------------------------------
# ..........
# Episode 19/51
# --------------------------------
# ..........
# Episode 20/51
# --------------------------------
# ..........
# Episode 21/51
# --------------------------------
# ..........
# Episode 22/51
# --------------------------------
# ..........
# Episode 23/51
# --------------------------------
# ..........
# Episode 24/51
# --------------------------------
# ..........
# Episode 25/51
# --------------------------------
# ..........
# Episode 26/51
# --------------------------------
# ..........
# Episode 27/51
# --------------------------------
# ..........
# Episode 28/51
# --------------------------------
# ..........
# Episode 29/51
# --------------------------------
# ..........
# Episode 30/51
# --------------------------------
# ..........
# Episode 31/51
# --------------------------------
# ..........
# Episode 32/51
# --------------------------------
# ..........
# Episode 33/51
# --------------------------------
# ..........
# Episode 34/51
# --------------------------------
# ..........
# Episode 35/51
# --------------------------------
# ..........
# Episode 36/51
# --------------------------------
# ..........
# Episode 37/51
# --------------------------------
# ..........
# Episode 38/51
# --------------------------------
# ..........
# Episode 39/51
# --------------------------------
# ..........
# Episode 40/51
# --------------------------------
# ..........
# Episode 41/51
# --------------------------------
# ..........
# Episode 42/51
# --------------------------------
# ..........
# Episode 43/51
# --------------------------------
# ..........
# Episode 44/51
# --------------------------------
# ..........
# Episode 45/51
# --------------------------------
# ..........
# Episode 46/51
# --------------------------------
# ..........
# Episode 47/51
# --------------------------------
# ..........
# Episode 48/51
# --------------------------------
# ..........
# Episode 49/51
# --------------------------------
# ..........
# Episode 50/51
# --------------------------------
# ..........
# Episode 51/51
# --------------------------------

# %%
print("Total google stocks in episodes"+ str(total_stock1bal))
print("Total walmart stocks in episodes"+ str(total_stock2bal))
print("Total Open cash in episodes"+ str(total_open_cash))
print("Total Portfolio value in episodes"+ str(total_port_value))
print("Total Days in episodes"+ str(total_days_played))

print("Benchmark_Profit is  " + str(int(Training_Benchmark_Portfolio_Value)) +"   with remaining google Stocks: " + str(remaining_stock1) + 
      "   and remaining walmart stocks: "+ str(remaining_stock2) )
# Out:
# Total google stocks in episodes[4463, 4469, 4452, 3718, 4637, 4449, 5110, 4451, 3228, 4449, 3213, 4614, 4469, 3251, 4454, 4446, 4453, 4462, 5670, 4620, 3547, 5622, 4458, 4439, 4477, 3257, 5049, 4454, 4453, 4468, 4463, 3192, 4617, 4484, 5666, 3234, 3210, 4468, 4450, 5035, 3221, 5683, 5712, 5687, 4455, 5706, 5677, 4450, 5484, 4446, 5706, 4452]
# Total walmart stocks in episodes[1275, 1491, 27, 763, 1258, 1481, 933, 1272, 1292, 1273, 1258, 1258, 910, 1258, 1269, 1483, 16, 1490, 1267, 1389, 1595, 1190, 109, 1474, 44, 1270, 1481, 1260, 1268, 1286, 39, 1267, 1345, 1472, 1249, 1265, 1267, 1248, 1228, 617, 1289, 1290, 1273, 1264, 1395, 1263, 1269, 970, 1042, 1479, 1282, 1497]
# Total Open cash in episodes[4759.8860999999952, 24.75051000000024, 44031.410769999966, 30509.38706999999, 4993.1023199999927, 14.664050000008444, 21554.773949999944, 5065.0535499999978, 6868.7822899999974, 4736.6325700000043, 7462.4050400000069, 4690.333090000001, 31961.259189999993, 7362.801709999997, 4429.0102700000025, 68.247770000001964, 44572.720779999967, 49.460460000007004, 3469.8388200000036, 53.720009999997558, 1047.0501400000082, 3618.4916199999889, 44118.934639999978, 60.021700000000862, 43325.750279999957, 6926.0220900000022, 0.65735000000039534, 5274.7547200000017, 5039.7371999999968, 4604.5981800000018, 43892.579309999965, 6914.5453299999999, 4.4130300000026352, 16.615060000003183, 3261.5219300000031, 7125.7609500000053, 6827.19884, 5047.6073599999972, 51.110349999999556, 34252.937859999991, 6930.1016200000004, 2568.7166999999968, 3018.9529000000002, 2969.9818399999963, 52.546029999998566, 2969.6244100000044, 3216.2692899999956, 23898.500129999989, 19235.221239999981, 17.94902000000468, 2732.437539999994, 38.429410000007429]
# Total Portfolio value in episodes[52391.301099999997, 99687.526209999996, 50323.990769999968, 60276.602069999994, 52272.012319999994, 104427.57165, 58630.738949999941, 52582.58855, 53576.607289999993, 52284.897570000001, 53025.39504000001, 51940.323090000005, 67536.944189999995, 52971.581710000006, 51849.535270000008, 108289.44897, 50501.96577999997, 92263.004260000016, 52289.363819999999, 82933.712010000003, 58180.690140000006, 49828.396619999985, 53136.224639999979, 97151.034899999999, 50211.835279999956, 52939.712090000001, 17560.42915, 52398.224720000006, 52427.122199999998, 52606.578180000004, 50596.094309999964, 52750.490330000001, 123618.92322999999, 107508.35985999998, 51479.70693, 52946.035950000005, 52684.833839999992, 51790.267359999998, 74922.780350000001, 60800.632859999991, 53530.071620000002, 52166.126699999993, 52087.927899999995, 51710.57183999999, 101997.31903, 51699.969410000005, 52110.509290000002, 61406.550129999989, 60374.116239999974, 107959.63021999999, 52092.442539999996, 98889.297010000009]
# Total Days in episodes[1499, 449, 1499, 1499, 1499, 450, 1499, 1499, 1499, 1499, 1499, 1499, 1499, 1499, 1499, 457, 1499, 447, 1499, 533, 1499, 1499, 1499, 455, 1499, 1499, 1084, 1499, 1499, 1499, 1499, 1499, 478, 457, 1499, 1499, 1499, 1499, 513, 1499, 1499, 1499, 1499, 1499, 460, 1499, 1499, 1499, 1499, 457, 1499, 452]
# Benchmark_Profit is  52655   with remaining google Stocks: 6.0   and remaining walmart stocks: 9.0

# %%
pd_data1_test=pd_data1_test.reset_index(drop=True)
pd_data2_test=pd_data2_test.reset_index(drop=True)

# %%
pd_data1_test.head()
# Out:
#         Date    Open    High     Low   Close     Volume  OpenInt
# 0 2003-05-15  1.1910  1.2076  1.1820  1.1999   79866509        0
# 1 2003-05-16  1.1898  1.2167  1.1704  1.2037   94069639        0
# 2 2003-05-19  1.1871  1.1935  1.1563  1.1589  124591981        0
# 3 2003-05-20  1.1589  1.1628  1.1271  1.1385  116368335        0
# 4 2003-05-21  1.1385  1.1577  1.1320  1.1437   85352801        0

# %%
pd_data2_test.head()
# Out:
#         Date   Open   High    Low  Close   Volume  OpenInt
# 0 2003-05-15  32.64  32.75  32.20  32.63  5222009        0
# 1 2003-05-16  32.51  33.16  32.38  33.05  7654816        0
# 2 2003-05-19  32.70  32.97  31.40  31.56  9798178        0
# 3 2003-05-20  31.56  32.13  31.17  31.48  8093492        0
# 4 2003-05-21  31.48  31.84  31.16  31.75  5217622        0

# %% [markdown]
# ## Benchmark model for Actual Test Run

# %%
#Initialize state and set benchmarking model

import datetime

#print(df_data1)
total_Prof=[]
done=False

Act_datasize = test
batch_size = 64


#To be removed
#Sstart_balance=500

#Benchmark Model

# Take Opening price in a new variable
data1_test=pd_data1_test['Open']
data2_test=pd_data2_test['Open']

data1_date=pd_data1_test['Date']



Act_Bench_Stock1_Bal=int(np.floor((start_balance/4)/data1_test[0]))
Act_Bench_Stock2_Bal=int(np.floor((start_balance/4)/data2_test[0]))
Act_Bench_Open_cash=start_balance/2




### Program to calculate benchmark profit


#sell 10% of stock in 10 intervals

interval=int(Act_datasize/10)
Total_Stock1_Amount= 0
Total_Stock2_Amount= 0
stocks2Value = 0
stocks1Value = 0

Act_stocks1=np.floor(Act_Bench_Stock1_Bal /10)
Act_stocks2=np.floor(Act_Bench_Stock2_Bal /10)
#print(str(Act_stocks1))
#print(str(Act_stocks2))

remaining_stock1=Act_Bench_Stock1_Bal
remaining_stock2=Act_Bench_Stock2_Bal
ttl=0

Benchmark_Port_Value=[]


for j in range (interval,Act_datasize+1,interval):
        #print("closing prices : " + str(data1_test[j-1]) )
        Price_closing_Stock1=data1_test[j-1]
        Price_closing_Stock2=data2_test[j-1]
        date_stock1=data1_date[j-1].strftime('%Y-%m-%d')
        #print(date_stock1)
        #np.array(pd_data1_test['Date'])
        
        stocks1Value= Act_stocks1 * Price_closing_Stock1
        stocks2Value= Act_stocks2 * Price_closing_Stock2
        remaining_stock1=remaining_stock1-Act_stocks1
        remaining_stock2=remaining_stock2-Act_stocks2
        #print("J is:"+ str(j))
        
        
        
        Stock1_Port_value=remaining_stock1*Price_closing_Stock1
        Stock2_Port_value=remaining_stock2*Price_closing_Stock2
        Act_Bench_Open_cash=Act_Bench_Open_cash+stocks1Value+stocks2Value #Adding 10% sold value into open cash
        
        Total_Portfolio_value=Act_Bench_Open_cash+Stock1_Port_value+Stock2_Port_value
        Benchmark_Port_Value.append([date_stock1,Total_Portfolio_value])
        



#print ("total_Test_Benchmark_amount : " +  str(Total_Portfolio_value))

Test_Benchmark_Portfolio_Value= Total_Portfolio_value




print("Benchmark_Profit is" + str(Test_Benchmark_Portfolio_Value) +"with remaining google Stocks: " + str(remaining_stock1) + 
      " and remaining walmart stocks: "+ str(remaining_stock2) )


#Define arrays to store per episode values 
total_Prof=[]
total_stock1bal=[]
total_stock2bal=[]
total_open_cash=[]
total_port_value=[]
total_days_played=[]


print(episode_count)
# Out:
# Benchmark_Profit is13725.1903with remaining google Stocks: 9.0 and remaining walmart stocks: 6.0
# 51

# %% [markdown]
# ## Actual test Run

# %%
#Actual run

import csv
episode_count=0


#Define arrays to store per episode values 
total_Prof=[]
total_stock1bal=[]
total_stock2bal=[]
total_open_cash=[]
total_port_value=[]
total_days_played=[]

from keras.models import load_model

model_name='model_ep10'

model = load_model("models/" + model_name)

Act_Bench_Stock1_Bal=int(np.floor((start_balance/4)/data1_test[0]))
Act_Bench_Stock2_Bal=int(np.floor((start_balance/4)/data2_test[0]))
Act_Bench_Open_cash=start_balance/2

# %%
#Actual run

import csv
episode_count=0


#Define arrays to store per episode values 
Act_total_Prof=[]
Act_total_stock1bal=[]
Act_total_stock2bal=[]
Act_total_open_cash=[]
Act_total_port_value=[]
Act_total_days_played=[]
actions_done_perday=[]
portfolio_value=[]

from keras.models import load_model

model_name='model_ep50'

model = load_model("models/" + model_name)


for e in range(1): #here we run only for 1 episode, as it is Test run

    Bal_stock1_t2=Act_Bench_Stock1_Bal
    Bal_stock2_t2=Act_Bench_Stock2_Bal
    done=False
    open_cash_t2= Act_Bench_Open_cash  
    total_profit = 0
    reward = 0
    
    #Initialize Agent
    agent_test = Agent(8, is_eval=True, model_name=model_name)
    #agent = Agent(8)

    agent_test.inventory1 =[]
    agent_test.inventory2 =[]
    for i in range(Bal_stock1_t2):
        agent_test.inventory1.append(data1_test[0])
    for i in range(Bal_stock2_t2):
        agent_test.inventory2.append(data2_test[0]) 
    
    
    #Timestep delta to make sure that with time reward increases for taking action
    timestep_delta=0
    
    #Running episode over all days in the datasize
    for t in range(Act_datasize):
        print("..........")
        
        print(pd_data1_test.iloc[t,0])
        state_class_obj= State(data1_test, data2_test, Bal_stock1_t2, Bal_stock2_t2, open_cash_t2,t)
        state_array_obj=state_class_obj.getState()
        action = agent_test.act(state_array_obj)
        
        print("Total portfolio value: " + str(state_class_obj.portfolio_value)+ 
                  "  stock 1 number: " + str(len(agent_test.inventory1))
                   +"  stock 2 number: "+str(len(agent_test.inventory2))+"  open cash"+str(state_class_obj.open_cash))


        
        #reward should be more as time goes further. We will remove reward_timedelta from actual reward 
        #reward_timedelta=(datasize-t)*timestep_delta
        
                   
        change_percent_stock1=(state_class_obj.Stock1Price-state_class_obj.fiveday_stock1)/state_class_obj.fiveday_stock1*100
        change_percent_stock2=(state_class_obj.Stock2Price-state_class_obj.fiveday_stock2)/state_class_obj.fiveday_stock2*100
        
        #print("change_percent_stock1:  "+str(change_percent_stock1))
        #print("change_percent_stock2:  "+str(change_percent_stock2))
        
        
        if action == 0:  #buy stock 1
            if state_class_obj.Stock1Price > state_class_obj.open_cash:
                '''
                print("Buy stock 1 when it did not have cash, so bankrupt, end of episode")
                reward=-reward_timedelta*10
                done = True
                '''
                #If agent is trying to buy when it has no cash but has stock1 and stock2 balance then, 
                #it should pick from other actions
                #if (state_class_obj.Stock1Blnc>1) and  (state_class_obj.Stock2Blnc>1):
                 #   action=random.sample([1, 2, 4, 5, 6],  1)  # Choose 1 elements from sell actions
                #else:    
                #print("Bankrupt")
              
                done = True
                #end episode
                     
            else:
                #print("In Buy stock 1")
                agent_test.inventory1.append(data1_test[t])
                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
                open_cash_t2=state_class_obj.open_cash-state_class_obj.Stock1Price #Here we are buying 1 stock
                
                
               
                
        if action == 1:  #sell stock 1
            if state_class_obj.Stock1Blnc <1 :
               # print("sold stock 2 when it did not have stock 2, so bankrupt, end of episode")
                
                done = True
                #end episode
            else:
                #print("In sell stock 1")
                agent_test.inventory1.pop(0)

                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
                open_cash_t2=state_class_obj.open_cash+state_class_obj.Stock1Price #State[0] is the price of stock 1. Here we are buying 1 stoc
          
                 
        


        
        if action == 2:             # Do nothing action    
                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
               # print("Do nothing")
        
        
        if action == 3:  #buy stock 2
            if state_class_obj.Stock2Price > state_class_obj.open_cash:
                '''
                print("Buy stock 2 when it did not have cash, so bankrupt, end of episode")
                reward=-reward_timedelta*10
                done = True
                
                '''
                #If agent is trying to buy when it has no cash but has stock1 and stock2 balance then, 
                #it should pick from other actions
                #if (state_class_obj.Stock1Blnc>1) and  (state_class_obj.Stock2Blnc>1):
                 #   action=random.sample([1, 2, 4, 5, 6],  1)  # Choose 1 elements from sell actions
                #else:    
                #print("Bankrupt")

                done = True
                     #end episode   
            else:
                #print("In Buy stock 2")
                agent.inventory2.append(data2_test[t])
                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
                open_cash_t2=state_class_obj.open_cash-state_class_obj.Stock2Price
                
              
        
        if action == 4:  #sell stock 2
            if state_class_obj.Stock2Blnc <1 :
                    #print("sold stock 2 when it did not have stock 2, so bankrupt, end of episode")
                    done = True
                #end episode
            else:
                #print("In sell stock 2")
                agent_test.inventory2.pop(0)
                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
                open_cash_t2=state_class_obj.open_cash+state_class_obj.Stock2Price
    

               # print("reward for selling stock2: " + str(reward))
            
        
        
        #print("reward:  "+str(reward))
        #if done!= False:done = True if t == datasize
        if t == Act_datasize-1:
            #print("t==datasize")
            done=True
            next_state_class_obj=State(data1_test, data2_test, Bal_stock1_t2, Bal_stock2_t2, open_cash_t2,t)
            next_state_array_obj=next_state_class_obj.getState()
        else:
            #print("t!=datasize"+str(open_cash_t2))
            next_state_class_obj=State(data1_test, data2_test, Bal_stock1_t2, Bal_stock2_t2, open_cash_t2,t+1)
            next_state_array_obj=next_state_class_obj.getState()
            
        #print("Action is "+str(action)+" reward is" + str(reward))


       
        
        actions_done_perday.append(action)
        portfolio_value.append(next_state_class_obj.portfolio_value)

        if done==True:
            print("--------------------------------")
            print("Total Profit: " + formatPrice(total_profit))
            print("Total No. of days played: " + str(t)+ "  out of overall days:  " + str(Act_datasize))
            print("Total portfolio value: " + str(next_state_class_obj.portfolio_value)+ 
                  "  stock 1 number: " + str(len(agent_test.inventory1))
                   +"  stock 2 number: "+str(len(agent_test.inventory2))+"  open cash"+str(next_state_class_obj.open_cash))

            Act_total_Prof.append(total_profit)
            Act_total_stock1bal.append(len(agent_test.inventory1))
            Act_total_stock2bal.append(len(agent_test.inventory2))
            Act_total_open_cash.append(state_class_obj.open_cash)
            Act_total_port_value.append(state_class_obj.portfolio_value)
            Act_total_days_played.append(t)


            print("--------------------------------")
            state_class_obj.reset()
            break
# Out:
# ..........
# 2003-05-15 00:00:00
# Total portfolio value: 9980.549  stock 1 number: 2099  stock 2 number: 76  open cash5000.0
# ..........
# 2003-05-16 00:00:00
# Total portfolio value: 9968.149  stock 1 number: 2100  stock 2 number: 76  open cash4998.809
# ..........
# 2003-05-19 00:00:00
# Total portfolio value: 9976.9163  stock 1 number: 2101  stock 2 number: 76  open cash4997.6192
# ..........
# 2003-05-20 00:00:00
# Total portfolio value: 9830.9999  stock 1 number: 2102  stock 2 number: 76  open cash4996.4321
# ..........
# 2003-05-21 00:00:00
# Total portfolio value: 9782.0187  stock 1 number: 2103  stock 2 number: 76  open cash4995.2732
# ..........
# 2003-05-22 00:00:00
# Total portfolio value: 9818.7395  stock 1 number: 2104  stock 2 number: 76  open cash4994.1347
# ..........
# 2003-05-23 00:00:00
# Total portfolio value: 9959.172  stock 1 number: 2105  stock 2 number: 76  open cash4992.9885
# ..........
# 2003-05-27 00:00:00
# Total portfolio value: 9887.7324  stock 1 number: 2106  stock 2 number: 76  open cash4991.8218
# ..........
# 2003-05-28 00:00:00
# Total portfolio value: 10137.2932  stock 1 number: 2107  stock 2 number: 76  open cash4990.6717
# ..........
# 2003-05-29 00:00:00
# Total portfolio value: 10108.3304  stock 1 number: 2108  stock 2 number: 76  open cash4989.4872
# ..........
# 2003-05-30 00:00:00
# Total portfolio value: 10141.3277  stock 1 number: 2109  stock 2 number: 76  open cash4988.3168
# ..........
# 2003-06-02 00:00:00
# Total portfolio value: 10206.4357  stock 1 number: 2110  stock 2 number: 76  open cash4987.1567
# ..........
# 2003-06-03 00:00:00
# Total portfolio value: 9981.3115  stock 1 number: 2111  stock 2 number: 76  open cash4985.9978
# ..........
# 2003-06-04 00:00:00
# Total portfolio value: 9984.5547  stock 1 number: 2112  stock 2 number: 76  open cash4984.8811
# ..........
# 2003-06-05 00:00:00
# Total portfolio value: 10015.5204  stock 1 number: 2113  stock 2 number: 76  open cash4983.7733
# ..........
# 2003-06-06 00:00:00
# Total portfolio value: 10122.7778  stock 1 number: 2114  stock 2 number: 76  open cash4982.6566
# ..........
# 2003-06-09 00:00:00
# Total portfolio value: 9895.3813  stock 1 number: 2115  stock 2 number: 76  open cash4981.5208
# ..........
# 2003-06-10 00:00:00
# Total portfolio value: 9855.6797  stock 1 number: 2116  stock 2 number: 76  open cash4980.4361
# ..........
# 2003-06-11 00:00:00
# Total portfolio value: 9884.2698  stock 1 number: 2117  stock 2 number: 76  open cash4979.354
# ..........
# 2003-06-12 00:00:00
# Total portfolio value: 10042.7476  stock 1 number: 2118  stock 2 number: 76  open cash4978.2566
# ..........
# 2003-06-13 00:00:00
# Total portfolio value: 10077.047  stock 1 number: 2119  stock 2 number: 76  open cash4977.1321
# ..........
# 2003-06-16 00:00:00
# Total portfolio value: 9992.767  stock 1 number: 2120  stock 2 number: 76  open cash4975.995
# ..........
# 2003-06-17 00:00:00
# Total portfolio value: 10207.2674  stock 1 number: 2121  stock 2 number: 76  open cash4974.8679
# ..........
# 2003-06-18 00:00:00
# Total portfolio value: 10177.346  stock 1 number: 2122  stock 2 number: 76  open cash4973.6884
# ..........
# 2003-06-19 00:00:00
# Total portfolio value: 10324.9784  stock 1 number: 2123  stock 2 number: 76  open cash4972.5076
# ..........
# 2003-06-20 00:00:00
# Total portfolio value: 10324.9784  stock 1 number: 2124  stock 2 number: 76  open cash4971.268
# ..........
# 2003-06-23 00:00:00
# Total portfolio value: 10259.7809  stock 1 number: 2125  stock 2 number: 76  open cash4970.0284
# ..........
# 2003-06-24 00:00:00
# Total portfolio value: 10305.6957  stock 1 number: 2126  stock 2 number: 76  open cash4968.7923
# ..........
# 2003-06-25 00:00:00
# Total portfolio value: 10208.2766  stock 1 number: 2127  stock 2 number: 76  open cash4967.5464
# ..........
# 2003-06-26 00:00:00
# Total portfolio value: 10190.371  stock 1 number: 2128  stock 2 number: 76  open cash4966.3438
# ..........
# 2003-06-27 00:00:00
# Total portfolio value: 10385.2433  stock 1 number: 2129  stock 2 number: 76  open cash4965.1464
# ..........
# 2003-06-30 00:00:00
# Total portfolio value: 10295.6963  stock 1 number: 2130  stock 2 number: 76  open cash4963.9103
# ..........
# 2003-07-01 00:00:00
# Total portfolio value: 10312.12  stock 1 number: 2131  stock 2 number: 76  open cash4962.7141
# ..........
# 2003-07-02 00:00:00
# Total portfolio value: 10418.4396  stock 1 number: 2132  stock 2 number: 76  open cash4961.5052
# ..........
# 2003-07-03 00:00:00
# Total portfolio value: 10369.0271  stock 1 number: 2133  stock 2 number: 76  open cash4960.286
# ..........
# 2003-07-07 00:00:00
# Total portfolio value: 10501.9449  stock 1 number: 2134  stock 2 number: 76  open cash4959.0693
# ..........
# 2003-07-08 00:00:00
# Total portfolio value: 10572.1324  stock 1 number: 2135  stock 2 number: 76  open cash4957.8359
# ..........
# 2003-07-09 00:00:00
# Total portfolio value: 10802.4644  stock 1 number: 2136  stock 2 number: 76  open cash4956.586
# ..........
# 2003-07-10 00:00:00
# Total portfolio value: 10648.8126  stock 1 number: 2137  stock 2 number: 76  open cash4955.2916
# ..........
# 2003-07-11 00:00:00
# Total portfolio value: 10556.133  stock 1 number: 2138  stock 2 number: 76  open cash4954.0186
# ..........
# 2003-07-14 00:00:00
# Total portfolio value: 10620.7439  stock 1 number: 2139  stock 2 number: 76  open cash4952.7598
# ..........
# 2003-07-15 00:00:00
# Total portfolio value: 10705.1039  stock 1 number: 2140  stock 2 number: 76  open cash4951.4779
# ..........
# 2003-07-16 00:00:00
# Total portfolio value: 10565.3133  stock 1 number: 2141  stock 2 number: 76  open cash4950.196
# ..........
# 2003-07-17 00:00:00
# Total portfolio value: 10542.5893  stock 1 number: 2142  stock 2 number: 76  open cash4948.9407
# ..........
# 2003-07-18 00:00:00
# Total portfolio value: 10575.5157  stock 1 number: 2143  stock 2 number: 76  open cash4947.6474
# ..........
# 2003-07-21 00:00:00
# Total portfolio value: 10426.1413  stock 1 number: 2144  stock 2 number: 76  open cash4946.3093
# ..........
# 2003-07-22 00:00:00
# Total portfolio value: 10525.1908  stock 1 number: 2145  stock 2 number: 76  open cash4944.9838
# ..........
# 2003-07-23 00:00:00
# Total portfolio value: 10689.7894  stock 1 number: 2146  stock 2 number: 76  open cash4943.6472
# ..........
# 2003-07-24 00:00:00
# Total portfolio value: 10954.3302  stock 1 number: 2147  stock 2 number: 76  open cash4942.3065
# ..........
# 2003-07-25 00:00:00
# Total portfolio value: 10845.7094  stock 1 number: 2148  stock 2 number: 76  open cash4940.9594
# ..........
# 2003-07-28 00:00:00
# Total portfolio value: 11051.85  stock 1 number: 2149  stock 2 number: 76  open cash4939.6519
# ..........
# 2003-07-29 00:00:00
# Total portfolio value: 11017.825  stock 1 number: 2150  stock 2 number: 76  open cash4938.275
# ..........
# 2003-07-30 00:00:00
# Total portfolio value: 10923.871  stock 1 number: 2151  stock 2 number: 76  open cash4936.9316
# ..........
# 2003-07-31 00:00:00
# Total portfolio value: 10936.4886  stock 1 number: 2152  stock 2 number: 76  open cash4935.6022
# ..........
# 2003-08-01 00:00:00
# Total portfolio value: 10976.5731  stock 1 number: 2153  stock 2 number: 76  open cash4934.274
# ..........
# 2003-08-04 00:00:00
# Total portfolio value: 10782.8547  stock 1 number: 2154  stock 2 number: 76  open cash4932.9293
# ..........
# 2003-08-05 00:00:00
# Total portfolio value: 10861.0322  stock 1 number: 2155  stock 2 number: 76  open cash4931.6142
# ..........
# 2003-08-06 00:00:00
# Total portfolio value: 10634.533  stock 1 number: 2156  stock 2 number: 76  open cash4930.2466
# ..........
# 2003-08-07 00:00:00
# Total portfolio value: 10619.4102  stock 1 number: 2157  stock 2 number: 76  open cash4928.9622
# ..........
# 2003-08-08 00:00:00
# Total portfolio value: 10679.3558  stock 1 number: 2158  stock 2 number: 76  open cash4927.6982
# ..........
# 2003-08-11 00:00:00
# Total portfolio value: 10629.6379  stock 1 number: 2159  stock 2 number: 76  open cash4926.411
# ..........
# 2003-08-12 00:00:00
# Total portfolio value: 10618.3899  stock 1 number: 2160  stock 2 number: 76  open cash4925.1419
# ..........
# 2003-08-13 00:00:00
# Total portfolio value: 10731.0203  stock 1 number: 2161  stock 2 number: 76  open cash4923.8766
# ..........
# 2003-08-14 00:00:00
# Total portfolio value: 10755.0177  stock 1 number: 2162  stock 2 number: 76  open cash4922.6049
# ..........
# 2003-08-15 00:00:00
# Total portfolio value: 10743.1045  stock 1 number: 2163  stock 2 number: 76  open cash4921.3105
# ..........
# 2003-08-18 00:00:00
# Total portfolio value: 10748.4713  stock 1 number: 2164  stock 2 number: 76  open cash4920.0325
# ..........
# 2003-08-19 00:00:00
# Total portfolio value: 11046.2858  stock 1 number: 2165  stock 2 number: 76  open cash4918.7608
# ..........
# 2003-08-20 00:00:00
# Total portfolio value: 10988.921  stock 1 number: 2166  stock 2 number: 76  open cash4917.4558
# ..........
# 2003-08-21 00:00:00
# Total portfolio value: 11196.0493  stock 1 number: 2167  stock 2 number: 76  open cash4916.1636
# ..........
# 2003-08-22 00:00:00
# Total portfolio value: 11464.7045  stock 1 number: 2168  stock 2 number: 76  open cash4914.8165
# ..........
# 2003-08-25 00:00:00
# Total portfolio value: 11208.3088  stock 1 number: 2169  stock 2 number: 76  open cash4913.4205
# ..........
# 2003-08-26 00:00:00
# Total portfolio value: 11266.2878  stock 1 number: 2170  stock 2 number: 76  open cash4912.0898
# ..........
# 2003-08-27 00:00:00
# Total portfolio value: 11297.1178  stock 1 number: 2171  stock 2 number: 76  open cash4910.7604
# ..........
# 2003-08-28 00:00:00
# Total portfolio value: 11361.081  stock 1 number: 2172  stock 2 number: 76  open cash4909.421
# ..........
# 2003-08-29 00:00:00
# Total portfolio value: 11479.5128  stock 1 number: 2173  stock 2 number: 76  open cash4908.056
# ..........
# 2003-09-02 00:00:00
# Total portfolio value: 11596.411  stock 1 number: 2174  stock 2 number: 76  open cash4906.6344
# ..........
# 2003-09-03 00:00:00
# Total portfolio value: 11696.3285  stock 1 number: 2175  stock 2 number: 76  open cash4905.1835
# ..........
# 2003-09-04 00:00:00
# Total portfolio value: 11641.7141  stock 1 number: 2176  stock 2 number: 76  open cash4903.7237
# ..........
# 2003-09-05 00:00:00
# Total portfolio value: 11639.7174  stock 1 number: 2177  stock 2 number: 76  open cash4902.2408
# ..........
# 2003-09-08 00:00:00
# Total portfolio value: 11569.3626  stock 1 number: 2178  stock 2 number: 76  open cash4900.785
# ..........
# 2003-09-09 00:00:00
# Total portfolio value: 11637.7944  stock 1 number: 2179  stock 2 number: 76  open cash4899.3458
# ..........
# 2003-09-10 00:00:00
# Total portfolio value: 11518.6364  stock 1 number: 2180  stock 2 number: 76  open cash4897.9024
# ..........
# 2003-09-11 00:00:00
# Total portfolio value: 11514.0764  stock 1 number: 2181  stock 2 number: 76  open cash4896.4781
# ..........
# 2003-09-12 00:00:00
# Total portfolio value: 11450.316  stock 1 number: 2182  stock 2 number: 76  open cash4895.0538
# ..........
# 2003-09-15 00:00:00
# Total portfolio value: 11593.9487  stock 1 number: 2183  stock 2 number: 76  open cash4893.6117
# ..........
# 2003-09-16 00:00:00
# Total portfolio value: 11450.1463  stock 1 number: 2184  stock 2 number: 76  open cash4892.1327
# ..........
# 2003-09-17 00:00:00
# Total portfolio value: 11533.1193  stock 1 number: 2185  stock 2 number: 76  open cash4890.7098
# ..........
# 2003-09-18 00:00:00
# Total portfolio value: 11490.8457  stock 1 number: 2186  stock 2 number: 76  open cash4889.2771
# ..........
# 2003-09-19 00:00:00
# Total portfolio value: 11730.1557  stock 1 number: 2187  stock 2 number: 76  open cash4887.862
# ..........
# 2003-09-22 00:00:00
# Total portfolio value: 11609.8745  stock 1 number: 2188  stock 2 number: 76  open cash4886.3969
# ..........
# 2003-09-23 00:00:00
# Total portfolio value: 11573.7511  stock 1 number: 2189  stock 2 number: 76  open cash4884.9767
# ..........
# 2003-09-24 00:00:00
# Total portfolio value: 11826.3181  stock 1 number: 2190  stock 2 number: 76  open cash4883.5671
# ..........
# 2003-09-25 00:00:00
# Total portfolio value: 11649.8675  stock 1 number: 2191  stock 2 number: 76  open cash4882.1442
# ..........
# 2003-09-26 00:00:00
# Total portfolio value: 11522.3395  stock 1 number: 2192  stock 2 number: 76  open cash4880.7779
# ..........
# 2003-09-29 00:00:00
# Total portfolio value: 11611.0489  stock 1 number: 2193  stock 2 number: 76  open cash4879.4781
# ..........
# 2003-09-30 00:00:00
# Total portfolio value: 11613.1831  stock 1 number: 2194  stock 2 number: 76  open cash4878.1025
# ..........
# 2003-10-01 00:00:00
# Total portfolio value: 11465.4181  stock 1 number: 2195  stock 2 number: 76  open cash4876.7526
# ..........
# 2003-10-02 00:00:00
# Total portfolio value: 11519.9377  stock 1 number: 2196  stock 2 number: 76  open cash4875.4257
# ..........
# 2003-10-03 00:00:00
# Total portfolio value: 11711.4235  stock 1 number: 2197  stock 2 number: 76  open cash4874.0937
# ..........
# 2003-10-06 00:00:00
# Total portfolio value: 11942.9945  stock 1 number: 2198  stock 2 number: 76  open cash4872.7503
# ..........
# 2003-10-07 00:00:00
# Total portfolio value: 12081.0101  stock 1 number: 2199  stock 2 number: 76  open cash4871.3624
# ..........
# 2003-10-08 00:00:00
# Total portfolio value: 12357.4301  stock 1 number: 2200  stock 2 number: 76  open cash4869.9501
# ..........
# 2003-10-09 00:00:00
# Total portfolio value: 12388.1951  stock 1 number: 2201  stock 2 number: 76  open cash4868.4619
# ..........
# 2003-10-10 00:00:00
# Total portfolio value: 12577.8983  stock 1 number: 2202  stock 2 number: 76  open cash4866.9687
# ..........
# 2003-10-13 00:00:00
# Total portfolio value: 12617.6842  stock 1 number: 2203  stock 2 number: 76  open cash4865.4639
# ..........
# 2003-10-14 00:00:00
# Total portfolio value: 12712.0534  stock 1 number: 2204  stock 2 number: 76  open cash4863.9438
# ..........
# 2003-10-15 00:00:00
# Total portfolio value: 12961.9454  stock 1 number: 2205  stock 2 number: 76  open cash4862.3864
# ..........
# 2003-10-16 00:00:00
# Total portfolio value: 12642.8986  stock 1 number: 2206  stock 2 number: 76  open cash4860.7946
# ..........
# 2003-10-17 00:00:00
# Total portfolio value: 12669.7289  stock 1 number: 2207  stock 2 number: 76  open cash4859.2706
# ..........
# 2003-10-20 00:00:00
# Total portfolio value: 12580.1929  stock 1 number: 2208  stock 2 number: 76  open cash4857.7737
# ..........
# 2003-10-21 00:00:00
# Total portfolio value: 12691.4134  stock 1 number: 2209  stock 2 number: 76  open cash4856.3263
# ..........
# 2003-10-22 00:00:00
# Total portfolio value: 12395.9184  stock 1 number: 2210  stock 2 number: 76  open cash4854.8344
# ..........
# 2003-10-23 00:00:00
# Total portfolio value: 12098.6038  stock 1 number: 2211  stock 2 number: 76  open cash4853.35
# ..........
# 2003-10-24 00:00:00
# Total portfolio value: 12193.5918  stock 1 number: 2212  stock 2 number: 76  open cash4851.8942
# ..........
# 2003-10-27 00:00:00
# Total portfolio value: 12217.993  stock 1 number: 2213  stock 2 number: 76  open cash4850.4494
# ..........
# 2003-10-28 00:00:00
# Total portfolio value: 12242.2194  stock 1 number: 2214  stock 2 number: 76  open cash4848.9922
# ..........
# 2003-10-29 00:00:00
# Total portfolio value: 12488.7374  stock 1 number: 2215  stock 2 number: 76  open cash4847.5474
# ..........
# 2003-10-30 00:00:00
# Total portfolio value: 12611.1094  stock 1 number: 2216  stock 2 number: 76  open cash4846.0414
# ..........
# 2003-10-31 00:00:00
# Total portfolio value: 12400.4482  stock 1 number: 2217  stock 2 number: 76  open cash4844.5059
# ..........
# 2003-11-03 00:00:00
# Total portfolio value: 12248.5338  stock 1 number: 2218  stock 2 number: 76  open cash4843.014
# ..........
# 2003-11-04 00:00:00
# Total portfolio value: 12429.9911  stock 1 number: 2219  stock 2 number: 76  open cash4841.5529
# ..........
# 2003-11-05 00:00:00
# Total portfolio value: 12349.5971  stock 1 number: 2220  stock 2 number: 76  open cash4840.0751
# ..........
# 2003-11-06 00:00:00
# Total portfolio value: 12416.1578  stock 1 number: 2221  stock 2 number: 76  open cash4838.614
# ..........
# 2003-11-07 00:00:00
# Total portfolio value: 12364.5094  stock 1 number: 2222  stock 2 number: 76  open cash4837.1462
# ..........
# 2003-11-10 00:00:00
# Total portfolio value: 12129.4224  stock 1 number: 2223  stock 2 number: 76  open cash4835.6606
# ..........
# 2003-11-11 00:00:00
# Total portfolio value: 11893.224  stock 1 number: 2224  stock 2 number: 76  open cash4834.224
# ..........
# 2003-11-12 00:00:00
# Total portfolio value: 11888.8515  stock 1 number: 2225  stock 2 number: 76  open cash4832.8215
# ..........
# 2003-11-13 00:00:00
# Total portfolio value: 12120.3303  stock 1 number: 2226  stock 2 number: 76  open cash4831.4459
# ..........
# 2003-11-14 00:00:00
# Total portfolio value: 12171.7949  stock 1 number: 2227  stock 2 number: 76  open cash4830.0165
# ..........
# 2003-11-17 00:00:00
# Total portfolio value: 11821.5101  stock 1 number: 2228  stock 2 number: 76  open cash4828.5773
# ..........
# 2003-11-18 00:00:00
# Total portfolio value: 11711.232  stock 1 number: 2229  stock 2 number: 76  open cash4827.2097
# ..........
# 2003-11-19 00:00:00
# Total portfolio value: 11463.383  stock 1 number: 2230  stock 2 number: 76  open cash4825.851
# ..........
# 2003-11-20 00:00:00
# Total portfolio value: 11427.8778  stock 1 number: 2231  stock 2 number: 76  open cash4824.5346
# ..........
# 2003-11-21 00:00:00
# Total portfolio value: 11454.4274  stock 1 number: 2232  stock 2 number: 76  open cash4823.2474
# ..........
# 2003-11-24 00:00:00
# Total portfolio value: 11445.0607  stock 1 number: 2233  stock 2 number: 76  open cash4821.9449
# ..........
# 2003-11-25 00:00:00
# Total portfolio value: 11761.2489  stock 1 number: 2234  stock 2 number: 76  open cash4820.6323
# ..........
# 2003-11-26 00:00:00
# Total portfolio value: 11825.0059  stock 1 number: 2235  stock 2 number: 76  open cash4819.2724
# ..........
# 2003-11-28 00:00:00
# Total portfolio value: 11800.7227  stock 1 number: 2236  stock 2 number: 76  open cash4817.9343
# ..........
# 2003-12-01 00:00:00
# Total portfolio value: 11964.4701  stock 1 number: 2237  stock 2 number: 76  open cash4816.6074
# ..........
# 2003-12-02 00:00:00
# Total portfolio value: 12052.1905  stock 1 number: 2238  stock 2 number: 76  open cash4815.2603
# ..........
# 2003-12-03 00:00:00
# Total portfolio value: 12014.1779  stock 1 number: 2239  stock 2 number: 76  open cash4813.8774
# ..........
# 2003-12-04 00:00:00
# Total portfolio value: 11740.2019  stock 1 number: 2240  stock 2 number: 76  open cash4812.4979
# ..........
# 2003-12-05 00:00:00
# Total portfolio value: 11701.0329  stock 1 number: 2241  stock 2 number: 76  open cash4811.1508
# ..........
# 2003-12-08 00:00:00
# Total portfolio value: 11711.0421  stock 1 number: 2242  stock 2 number: 76  open cash4809.8127
# ..........
# 2003-12-09 00:00:00
# Total portfolio value: 11739.5829  stock 1 number: 2243  stock 2 number: 76  open cash4808.482
# ..........
# 2003-12-10 00:00:00
# Total portfolio value: 11502.4973  stock 1 number: 2244  stock 2 number: 76  open cash4807.1257
# ..........
# 2003-12-11 00:00:00
# Total portfolio value: 11458.8723  stock 1 number: 2245  stock 2 number: 76  open cash4805.8168
# ..........
# 2003-12-12 00:00:00
# Total portfolio value: 11731.1109  stock 1 number: 2246  stock 2 number: 76  open cash4804.5209
# ..........
# 2003-12-15 00:00:00
# Total portfolio value: 11849.9291  stock 1 number: 2247  stock 2 number: 76  open cash4803.1559
# ..........
# 2003-12-16 00:00:00
# Total portfolio value: 11478.7187  stock 1 number: 2248  stock 2 number: 76  open cash4801.7803
# ..........
# 2003-12-17 00:00:00
# Total portfolio value: 11452.1961  stock 1 number: 2249  stock 2 number: 76  open cash4800.487
# ..........
# 2003-12-18 00:00:00
# Total portfolio value: 11284.7361  stock 1 number: 2250  stock 2 number: 76  open cash4799.2011
# ..........
# 2003-12-19 00:00:00
# Total portfolio value: 11417.9451  stock 1 number: 2251  stock 2 number: 76  open cash4797.9268
# ..........
# 2003-12-22 00:00:00
# Total portfolio value: 11351.0035  stock 1 number: 2252  stock 2 number: 76  open cash4796.6335
# ..........
# 2003-12-23 00:00:00
# Total portfolio value: 11470.3722  stock 1 number: 2253  stock 2 number: 76  open cash4795.376
# ..........
# 2003-12-24 00:00:00
# Total portfolio value: 11614.801  stock 1 number: 2254  stock 2 number: 76  open cash4794.1006
# ..........
# 2003-12-26 00:00:00
# Total portfolio value: 11847.3215  stock 1 number: 2255  stock 2 number: 76  open cash4792.838
# ..........
# 2003-12-29 00:00:00
# Total portfolio value: 11901.2607  stock 1 number: 2256  stock 2 number: 76  open cash4791.5343
# ..........
# 2003-12-30 00:00:00
# Total portfolio value: 11893.044  stock 1 number: 2257  stock 2 number: 76  open cash4790.1949
# ..........
# 2003-12-31 00:00:00
# Total portfolio value: 11891.1994  stock 1 number: 2258  stock 2 number: 76  open cash4788.8386
# ..........
# 2004-01-02 00:00:00
# Total portfolio value: 11916.2323  stock 1 number: 2259  stock 2 number: 76  open cash4787.471
# ..........
# 2004-01-05 00:00:00
# Total portfolio value: 11836.9203  stock 1 number: 2260  stock 2 number: 76  open cash4786.0903
# ..........
# 2004-01-06 00:00:00
# Total portfolio value: 12041.4211  stock 1 number: 2261  stock 2 number: 76  open cash4784.7188
# ..........
# 2004-01-07 00:00:00
# Total portfolio value: 11949.9307  stock 1 number: 2262  stock 2 number: 76  open cash4783.2945
# ..........
# 2004-01-08 00:00:00
# Total portfolio value: 12050.1306  stock 1 number: 2263  stock 2 number: 76  open cash4781.8794
# ..........
# 2004-01-09 00:00:00
# Total portfolio value: 11932.2218  stock 1 number: 2264  stock 2 number: 76  open cash4780.417
# ..........
# 2004-01-12 00:00:00
# Total portfolio value: 12063.0973  stock 1 number: 2265  stock 2 number: 76  open cash4778.9288
# ..........
# 2004-01-13 00:00:00
# Total portfolio value: 12364.0449  stock 1 number: 2266  stock 2 number: 76  open cash4777.4459
# ..........
# 2004-01-14 00:00:00
# Total portfolio value: 12468.7185  stock 1 number: 2267  stock 2 number: 76  open cash4775.8644
# ..........
# 2004-01-15 00:00:00
# Total portfolio value: 12262.7525  stock 1 number: 2268  stock 2 number: 76  open cash4774.3021
# ..........
# 2004-01-16 00:00:00
# Total portfolio value: 12388.0975  stock 1 number: 2269  stock 2 number: 76  open cash4772.8343
# ..........
# 2004-01-20 00:00:00
# Total portfolio value: 12290.9485  stock 1 number: 2270  stock 2 number: 76  open cash4771.3615
# ..........
# 2004-01-21 00:00:00
# Total portfolio value: 12337.9808  stock 1 number: 2271  stock 2 number: 76  open cash4769.9094
# ..........
# 2004-01-22 00:00:00
# Total portfolio value: 12368.6016  stock 1 number: 2272  stock 2 number: 76  open cash4768.456
# ..........
# 2004-01-23 00:00:00
# Total portfolio value: 12344.0451  stock 1 number: 2273  stock 2 number: 76  open cash4767.0112
# ..........
# 2004-01-26 00:00:00
# Total portfolio value: 12352.9315  stock 1 number: 2274  stock 2 number: 76  open cash4765.5869
# ..........
# 2004-01-27 00:00:00
# Total portfolio value: 12433.0015  stock 1 number: 2275  stock 2 number: 76  open cash4764.149
# ..........
# 2004-01-28 00:00:00
# Total portfolio value: 12175.3363  stock 1 number: 2276  stock 2 number: 76  open cash4762.6739
# ..........
# 2004-01-29 00:00:00
# Total portfolio value: 12013.9537  stock 1 number: 2277  stock 2 number: 76  open cash4761.2115
# ..........
# 2004-01-30 00:00:00
# Total portfolio value: 11822.8753  stock 1 number: 2278  stock 2 number: 76  open cash4759.7629
# ..........
# 2004-02-02 00:00:00
# Total portfolio value: 11877.8412  stock 1 number: 2279  stock 2 number: 76  open cash4758.3071
# ..........
# 2004-02-03 00:00:00
# Total portfolio value: 11675.6052  stock 1 number: 2280  stock 2 number: 76  open cash4756.8692
# ..........
# 2004-02-04 00:00:00
# Total portfolio value: 11373.0295  stock 1 number: 2281  stock 2 number: 76  open cash4755.441
# ..........
# 2004-02-05 00:00:00
# Total portfolio value: 11440.9511  stock 1 number: 2282  stock 2 number: 76  open cash4754.0325
# ..........
# 2004-02-06 00:00:00
# Total portfolio value: 11543.593  stock 1 number: 2283  stock 2 number: 76  open cash4752.6352
# ..........
# 2004-02-09 00:00:00
# Total portfolio value: 11612.801  stock 1 number: 2284  stock 2 number: 76  open cash4751.1986
# ..........
# 2004-02-10 00:00:00
# Total portfolio value: 11544.401  stock 1 number: 2285  stock 2 number: 76  open cash4749.75
# ..........
# 2004-02-11 00:00:00
# Total portfolio value: 11611.9122  stock 1 number: 2286  stock 2 number: 76  open cash4748.3014
# ..........
# 2004-02-12 00:00:00
# Total portfolio value: 11786.373  stock 1 number: 2287  stock 2 number: 76  open cash4746.8236
# ..........
# 2004-02-13 00:00:00
# Total portfolio value: 11834.4962  stock 1 number: 2288  stock 2 number: 76  open cash4745.3074
# ..........
# 2004-02-17 00:00:00
# Total portfolio value: 11635.8508  stock 1 number: 2289  stock 2 number: 76  open cash4743.7798
# ..........
# 2004-02-18 00:00:00
# Total portfolio value: 11588.9368  stock 1 number: 2290  stock 2 number: 76  open cash4742.3008
# ..........
# 2004-02-19 00:00:00
# Total portfolio value: 11590.1593  stock 1 number: 2291  stock 2 number: 76  open cash4740.8164
# ..........
# 2004-02-20 00:00:00
# Total portfolio value: 11445.9797  stock 1 number: 2292  stock 2 number: 76  open cash4739.3245
# ..........
# 2004-02-23 00:00:00
# Total portfolio value: 11466.4477  stock 1 number: 2293  stock 2 number: 76  open cash4737.8839
# ..........
# 2004-02-24 00:00:00
# Total portfolio value: 11325.0511  stock 1 number: 2294  stock 2 number: 76  open cash4736.4473
# ..........
# 2004-02-25 00:00:00
# Total portfolio value: 11230.5851  stock 1 number: 2295  stock 2 number: 76  open cash4735.0296
# ..........
# 2004-02-26 00:00:00
# Total portfolio value: 11359.2771  stock 1 number: 2296  stock 2 number: 76  open cash4733.6067
# ..........
# 2004-02-27 00:00:00
# Total portfolio value: 11410.3331  stock 1 number: 2297  stock 2 number: 76  open cash4732.1443
# ..........
# 2004-03-01 00:00:00
# Total portfolio value: 11533.0699  stock 1 number: 2298  stock 2 number: 76  open cash4730.6739
# ..........
# 2004-03-02 00:00:00
# Total portfolio value: 11504.1975  stock 1 number: 2299  stock 2 number: 76  open cash4729.1319
# ..........
# 2004-03-03 00:00:00
# Total portfolio value: 11374.0775  stock 1 number: 2300  stock 2 number: 76  open cash4727.5975
# ..........
# 2004-03-04 00:00:00
# Total portfolio value: 11536.9007  stock 1 number: 2301  stock 2 number: 76  open cash4726.0863
# ..........
# 2004-03-05 00:00:00
# Total portfolio value: 11723.7961  stock 1 number: 2302  stock 2 number: 76  open cash4724.5519
# ..........
# 2004-03-08 00:00:00
# Total portfolio value: 12015.6095  stock 1 number: 2303  stock 2 number: 76  open cash4722.9548
# ..........
# 2004-03-09 00:00:00
# Total portfolio value: 11831.0127  stock 1 number: 2304  stock 2 number: 76  open cash4721.2399
# ..........
# 2004-03-10 00:00:00
# Total portfolio value: 11947.9587  stock 1 number: 2305  stock 2 number: 76  open cash4719.5817
# ..........
# 2004-03-11 00:00:00
# Total portfolio value: 11865.5867  stock 1 number: 2306  stock 2 number: 76  open cash4717.8543
# ..........
# 2004-03-12 00:00:00
# Total portfolio value: 11893.8826  stock 1 number: 2307  stock 2 number: 76  open cash4716.1089
# ..........
# 2004-03-15 00:00:00
# Total portfolio value: 11922.4218  stock 1 number: 2308  stock 2 number: 76  open cash4714.3598
# ..........
# 2004-03-16 00:00:00
# Total portfolio value: 11790.2737  stock 1 number: 2309  stock 2 number: 76  open cash4712.6283
# ..........
# 2004-03-17 00:00:00
# Total portfolio value: 11818.6097  stock 1 number: 2310  stock 2 number: 76  open cash4710.9277
# ..........
# 2004-03-18 00:00:00
# Total portfolio value: 11779.8854  stock 1 number: 2311  stock 2 number: 76  open cash4709.2655
# ..........
# 2004-03-19 00:00:00
# Total portfolio value: 11786.543  stock 1 number: 2312  stock 2 number: 76  open cash4707.6046
# ..........
# 2004-03-22 00:00:00
# Total portfolio value: 11637.8152  stock 1 number: 2313  stock 2 number: 76  open cash4705.9589
# ..........
# 2004-03-23 00:00:00
# Total portfolio value: 11676.6082  stock 1 number: 2314  stock 2 number: 76  open cash4704.3338
# ..........
# 2004-03-24 00:00:00
# Total portfolio value: 11519.3427  stock 1 number: 2315  stock 2 number: 76  open cash4702.6742
# ..........
# 2004-03-25 00:00:00
# Total portfolio value: 11611.7851  stock 1 number: 2316  stock 2 number: 76  open cash4701.0543
# ..........
# 2004-03-26 00:00:00
# Total portfolio value: 11885.7242  stock 1 number: 2317  stock 2 number: 76  open cash4699.383
# ..........
# 2004-03-29 00:00:00
# Total portfolio value: 11961.6786  stock 1 number: 2318  stock 2 number: 76  open cash4697.6594
# ..........
# 2004-03-30 00:00:00
# Total portfolio value: 12078.961  stock 1 number: 2319  stock 2 number: 76  open cash4695.905
# ..........
# 2004-03-31 00:00:00
# Total portfolio value: 12165.601  stock 1 number: 2320  stock 2 number: 76  open cash4694.121
# ..........
# 2004-04-01 00:00:00
# Total portfolio value: 11991.2353  stock 1 number: 2321  stock 2 number: 76  open cash4692.337
# ..........
# 2004-04-02 00:00:00
# Total portfolio value: 12300.8389  stock 1 number: 2322  stock 2 number: 76  open cash4690.6147
# ..........
# 2004-04-05 00:00:00
# Total portfolio value: 12247.3094  stock 1 number: 2323  stock 2 number: 76  open cash4688.8386
# ..........
# 2004-04-06 00:00:00
# Total portfolio value: 12334.2954  stock 1 number: 2324  stock 2 number: 76  open cash4687.079
# ..........
# 2004-04-07 00:00:00
# Total portfolio value: 12308.0329  stock 1 number: 2325  stock 2 number: 76  open cash4685.3029
# ..........
# 2004-04-08 00:00:00
# Total portfolio value: 12475.4713  stock 1 number: 2326  stock 2 number: 76  open cash4683.5345
# ..........
# 2004-04-12 00:00:00
# Total portfolio value: 12431.6274  stock 1 number: 2327  stock 2 number: 76  open cash4681.7477
# ..........
# 2004-04-13 00:00:00
# Total portfolio value: 12501.3922  stock 1 number: 2328  stock 2 number: 76  open cash4679.9866
# ..........
# 2004-04-14 00:00:00
# Total portfolio value: 12160.8535  stock 1 number: 2329  stock 2 number: 76  open cash4678.1939
# ..........
# 2004-04-15 00:00:00
# Total portfolio value: 12570.7315  stock 1 number: 2330  stock 2 number: 76  open cash4676.4815
# ..........
# 2004-04-16 00:00:00
# Total portfolio value: 12592.4996  stock 1 number: 2331  stock 2 number: 76  open cash4674.6245
# ..........
# 2004-04-19 00:00:00
# Total portfolio value: 12318.8884  stock 1 number: 2332  stock 2 number: 76  open cash4672.7624
# ..........
# 2004-04-20 00:00:00
# Total portfolio value: 12506.2795  stock 1 number: 2333  stock 2 number: 76  open cash4670.9619
# ..........
# 2004-04-21 00:00:00
# Total portfolio value: 12233.0329  stock 1 number: 2334  stock 2 number: 76  open cash4669.1547
# ..........
# 2004-04-22 00:00:00
# Total portfolio value: 12280.6289  stock 1 number: 2335  stock 2 number: 76  open cash4667.3874
# ..........
# 2004-04-23 00:00:00
# Total portfolio value: 12309.2993  stock 1 number: 2336  stock 2 number: 76  open cash4665.6225
# ..........
# 2004-04-26 00:00:00
# Total portfolio value: 12306.2194  stock 1 number: 2337  stock 2 number: 76  open cash4663.8437
# ..........
# 2004-04-27 00:00:00
# Total portfolio value: 12359.6634  stock 1 number: 2338  stock 2 number: 76  open cash4662.0776
# ..........
# 2004-04-28 00:00:00
# Total portfolio value: 12296.2182  stock 1 number: 2339  stock 2 number: 76  open cash4660.3335
# ..........
# 2004-04-29 00:00:00
# Total portfolio value: 12186.9162  stock 1 number: 2340  stock 2 number: 76  open cash4658.6162
# ..........
# 2004-04-30 00:00:00
# Total portfolio value: 12189.3875  stock 1 number: 2341  stock 2 number: 76  open cash4656.9232
# ..........
# 2004-05-03 00:00:00
# Total portfolio value: 11856.3625  stock 1 number: 2342  stock 2 number: 76  open cash4655.2009
# ..........
# 2004-05-04 00:00:00
# Total portfolio value: 11938.4602  stock 1 number: 2343  stock 2 number: 76  open cash4653.5361
# ..........
# 2004-05-05 00:00:00
# Total portfolio value: 11925.413  stock 1 number: 2344  stock 2 number: 76  open cash4651.8674
# ..........
# 2004-05-06 00:00:00
# Total portfolio value: 11927.7865  stock 1 number: 2345  stock 2 number: 76  open cash4650.19
# ..........
# 2004-05-07 00:00:00
# Total portfolio value: 11906.3503  stock 1 number: 2346  stock 2 number: 76  open cash4648.4983
# ..........
# 2004-05-10 00:00:00
# Total portfolio value: 11728.2768  stock 1 number: 2347  stock 2 number: 76  open cash4646.7963
# ..........
# 2004-05-11 00:00:00
# Total portfolio value: 11799.334  stock 1 number: 2348  stock 2 number: 76  open cash4645.1148
# ..........
# 2004-05-12 00:00:00
# Total portfolio value: 11862.2045  stock 1 number: 2349  stock 2 number: 76  open cash4643.4244
# ..........
# 2004-05-13 00:00:00
# Total portfolio value: 11951.1995  stock 1 number: 2350  stock 2 number: 76  open cash4641.7095
# ..........
# 2004-05-14 00:00:00
# Total portfolio value: 12037.5334  stock 1 number: 2351  stock 2 number: 76  open cash4639.9729
# ..........
# 2004-05-17 00:00:00
# Total portfolio value: 11869.6918  stock 1 number: 2352  stock 2 number: 76  open cash4638.2374
# ..........
# 2004-05-18 00:00:00
# Total portfolio value: 11908.281  stock 1 number: 2353  stock 2 number: 76  open cash4636.5277
# ..........
# 2004-05-19 00:00:00
# Total portfolio value: 11985.5392  stock 1 number: 2354  stock 2 number: 76  open cash4634.8016
# ..........
# 2004-05-20 00:00:00
# Total portfolio value: 11812.3092  stock 1 number: 2355  stock 2 number: 76  open cash4633.0472
# ..........
# 2004-05-21 00:00:00
# Total portfolio value: 11818.7616  stock 1 number: 2356  stock 2 number: 76  open cash4631.3428
# ..........
# 2004-05-24 00:00:00
# Total portfolio value: 11874.7042  stock 1 number: 2357  stock 2 number: 76  open cash4629.6205
# ..........
# 2004-05-25 00:00:00
# Total portfolio value: 11953.5502  stock 1 number: 2358  stock 2 number: 76  open cash4627.8764
# ..........
# 2004-05-26 00:00:00
# Total portfolio value: 12221.0633  stock 1 number: 2359  stock 2 number: 76  open cash4626.1153
# ..........
# 2004-05-27 00:00:00
# Total portfolio value: 12367.5233  stock 1 number: 2360  stock 2 number: 76  open cash4624.3033
# ..........
# 2004-05-28 00:00:00
# Total portfolio value: 12459.8417  stock 1 number: 2361  stock 2 number: 76  open cash4622.4798
# ..........
# 2004-06-01 00:00:00
# Total portfolio value: 12461.0875  stock 1 number: 2362  stock 2 number: 76  open cash4620.6819
# ..........
# 2004-06-02 00:00:00
# Total portfolio value: 12694.9244  stock 1 number: 2363  stock 2 number: 76  open cash4618.9031
# ..........
# 2004-06-03 00:00:00
# Total portfolio value: 12759.184  stock 1 number: 2364  stock 2 number: 76  open cash4617.108
# ..........
# 2004-06-04 00:00:00
# Total portfolio value: 12756.341  stock 1 number: 2365  stock 2 number: 76  open cash4615.269
# ..........
# 2004-06-07 00:00:00
# Total portfolio value: 12941.4572  stock 1 number: 2366  stock 2 number: 76  open cash4613.4402
# ..........
# 2004-06-08 00:00:00
# Total portfolio value: 13052.4426  stock 1 number: 2367  stock 2 number: 76  open cash4611.5807
# ..........
# 2004-06-09 00:00:00
# Total portfolio value: 13092.5066  stock 1 number: 2368  stock 2 number: 76  open cash4609.665
# ..........
# 2004-06-10 00:00:00
# Total portfolio value: 13015.7972  stock 1 number: 2369  stock 2 number: 76  open cash4607.7388
# ..........
# 2004-06-14 00:00:00
# Total portfolio value: 13013.4712  stock 1 number: 2370  stock 2 number: 76  open cash4605.8052
# ..........
# 2004-06-15 00:00:00
# Total portfolio value: 12978.133  stock 1 number: 2371  stock 2 number: 76  open cash4603.8434
# ..........
# 2004-06-16 00:00:00
# Total portfolio value: 13060.809  stock 1 number: 2372  stock 2 number: 76  open cash4601.9058
# ..........
# 2004-06-17 00:00:00
# Total portfolio value: 13411.9424  stock 1 number: 2373  stock 2 number: 76  open cash4599.9452
# ..........
# 2004-06-18 00:00:00
# Total portfolio value: 13327.4502  stock 1 number: 2374  stock 2 number: 76  open cash4597.8488
# ..........
# 2004-06-21 00:00:00
# Total portfolio value: 13401.5027  stock 1 number: 2375  stock 2 number: 76  open cash4595.7627
# ..........
# 2004-06-22 00:00:00
# Total portfolio value: 13282.6539  stock 1 number: 2376  stock 2 number: 76  open cash4593.6419
# ..........
# 2004-06-23 00:00:00
# Total portfolio value: 13321.4534  stock 1 number: 2377  stock 2 number: 76  open cash4591.5724
# ..........
# 2004-06-24 00:00:00
# Total portfolio value: 13593.3786  stock 1 number: 2378  stock 2 number: 76  open cash4589.4594
# ..........
# 2004-06-25 00:00:00
# Total portfolio value: 13491.65  stock 1 number: 2379  stock 2 number: 76  open cash4587.303
# ..........
# 2004-06-28 00:00:00
# Total portfolio value: 13718.894  stock 1 number: 2380  stock 2 number: 76  open cash4585.19
# ..........
# 2004-06-29 00:00:00
# Total portfolio value: 13524.1647  stock 1 number: 2381  stock 2 number: 76  open cash4583.0192
# ..........
# 2004-06-30 00:00:00
# Total portfolio value: 13619.1057  stock 1 number: 2382  stock 2 number: 76  open cash4580.9637
# ..........
# 2004-07-01 00:00:00
# Total portfolio value: 13561.3213  stock 1 number: 2383  stock 2 number: 76  open cash4578.8827
# ..........
# 2004-07-02 00:00:00
# Total portfolio value: 13221.3213  stock 1 number: 2384  stock 2 number: 76  open cash4576.8285
# ..........
# 2004-07-06 00:00:00
# Total portfolio value: 13306.7683  stock 1 number: 2385  stock 2 number: 76  open cash4574.8793
# ..........
# 2004-07-07 00:00:00
# Total portfolio value: 13138.5971  stock 1 number: 2386  stock 2 number: 76  open cash4572.8879
# ..........
# 2004-07-08 00:00:00
# Total portfolio value: 12863.5239  stock 1 number: 2387  stock 2 number: 76  open cash4570.9157
# ..........
# 2004-07-09 00:00:00
# Total portfolio value: 12982.2959  stock 1 number: 2388  stock 2 number: 76  open cash4568.9871
# ..........
# 2004-07-12 00:00:00
# Total portfolio value: 12819.0631  stock 1 number: 2389  stock 2 number: 76  open cash4567.0495
# ..........
# 2004-07-13 00:00:00
# Total portfolio value: 12775.0851  stock 1 number: 2390  stock 2 number: 76  open cash4565.1271
# ..........
# 2004-07-14 00:00:00
# Total portfolio value: 12725.2071  stock 1 number: 2391  stock 2 number: 76  open cash4563.2549
# ..........
# 2004-07-15 00:00:00
# Total portfolio value: 13312.6919  stock 1 number: 2392  stock 2 number: 76  open cash4561.4007
# ..........
# 2004-07-16 00:00:00
# Total portfolio value: 13326.5225  stock 1 number: 2393  stock 2 number: 76  open cash4559.3171
# ..........
# 2004-07-19 00:00:00
# Total portfolio value: 13060.2603  stock 1 number: 2394  stock 2 number: 76  open cash4557.2093
# ..........
# 2004-07-20 00:00:00
# Total portfolio value: 12956.4593  stock 1 number: 2395  stock 2 number: 76  open cash4555.1578
# ..........
# 2004-07-21 00:00:00
# Total portfolio value: 13104.8413  stock 1 number: 2396  stock 2 number: 76  open cash4553.1141
# ..........
# 2004-07-22 00:00:00
# Total portfolio value: 12682.5455  stock 1 number: 2397  stock 2 number: 76  open cash4551.0459
# ..........
# 2004-07-23 00:00:00
# Total portfolio value: 12643.9797  stock 1 number: 2398  stock 2 number: 76  open cash4549.0391
# ..........
# 2004-07-26 00:00:00
# Total portfolio value: 12327.6733  stock 1 number: 2399  stock 2 number: 76  open cash4547.0094
# ..........
# 2004-07-27 00:00:00
# Total portfolio value: 12403.5933  stock 1 number: 2400  stock 2 number: 76  open cash4545.0333
# ..........
# 2004-07-28 00:00:00
# Total portfolio value: 12491.8291  stock 1 number: 2401  stock 2 number: 76  open cash4542.9996
# ..........
# 2004-07-29 00:00:00
# Total portfolio value: 12449.5321  stock 1 number: 2402  stock 2 number: 76  open cash4540.9301
# ..........
# 2004-07-30 00:00:00
# Total portfolio value: 12493.1266  stock 1 number: 2403  stock 2 number: 76  open cash4538.8491
# ..........
# 2004-08-02 00:00:00
# Total portfolio value: 12266.9178  stock 1 number: 2404  stock 2 number: 76  open cash4536.7566
# ..........
# 2004-08-03 00:00:00
# Total portfolio value: 12295.1618  stock 1 number: 2405  stock 2 number: 76  open cash4534.7563
# ..........
# 2004-08-04 00:00:00
# Total portfolio value: 12140.5654  stock 1 number: 2406  stock 2 number: 76  open cash4532.7392
# ..........
# 2004-08-05 00:00:00
# Total portfolio value: 12274.3374  stock 1 number: 2407  stock 2 number: 76  open cash4530.7415
# ..........
# 2004-08-06 00:00:00
# Total portfolio value: 11972.4174  stock 1 number: 2408  stock 2 number: 76  open cash4528.7078
# ..........
# 2004-08-09 00:00:00
# Total portfolio value: 11818.0953  stock 1 number: 2409  stock 2 number: 76  open cash4526.7291
# ..........
# 2004-08-10 00:00:00
# Total portfolio value: 11927.5623  stock 1 number: 2410  stock 2 number: 76  open cash4524.8173
# ..........
# 2004-08-11 00:00:00
# Total portfolio value: 12090.5362  stock 1 number: 2411  stock 2 number: 76  open cash4522.8708
# ..........
# 2004-08-12 00:00:00
# Total portfolio value: 11992.641  stock 1 number: 2412  stock 2 number: 76  open cash4520.8794
# ..........
# 2004-08-13 00:00:00
# Total portfolio value: 12034.4429  stock 1 number: 2413  stock 2 number: 76  open cash4518.9226
# ..........
# 2004-08-16 00:00:00
# Total portfolio value: 12036.8017  stock 1 number: 2414  stock 2 number: 76  open cash4516.9595
# ..........
# 2004-08-17 00:00:00
# Total portfolio value: 12172.4147  stock 1 number: 2415  stock 2 number: 76  open cash4514.9822
# ..........
# 2004-08-18 00:00:00
# Total portfolio value: 12116.2899  stock 1 number: 2416  stock 2 number: 76  open cash4513.0227
# ..........
# 2004-08-19 00:00:00
# Total portfolio value: 12454.8979  stock 1 number: 2417  stock 2 number: 76  open cash4511.0685
# ..........
# 2004-08-20 00:00:00
# Total portfolio value: 12193.7431  stock 1 number: 2418  stock 2 number: 76  open cash4509.0503
# ..........
# 2004-08-23 00:00:00
# Total portfolio value: 12309.4725  stock 1 number: 2419  stock 2 number: 76  open cash4507.0807
# ..........
# 2004-08-24 00:00:00
# Total portfolio value: 12369.9805  stock 1 number: 2420  stock 2 number: 76  open cash4505.1085
# ..........
# 2004-08-25 00:00:00
# Total portfolio value: 12415.6646  stock 1 number: 2421  stock 2 number: 76  open cash4503.1069
# ..........
# 2004-08-26 00:00:00
# Total portfolio value: 12697.618  stock 1 number: 2422  stock 2 number: 76  open cash4501.0632
# ..........
# 2004-08-27 00:00:00
# Total portfolio value: 12930.414  stock 1 number: 2423  stock 2 number: 76  open cash4498.9398
# ..........
# 2004-08-30 00:00:00
# Total portfolio value: 12805.2812  stock 1 number: 2424  stock 2 number: 76  open cash4496.7244
# ..........
# 2004-08-31 00:00:00
# Total portfolio value: 12711.3787  stock 1 number: 2425  stock 2 number: 76  open cash4494.5462
# ..........
# 2004-09-01 00:00:00
# Total portfolio value: 12725.5827  stock 1 number: 2426  stock 2 number: 76  open cash4492.3641
# ..........
# 2004-09-02 00:00:00
# Total portfolio value: 12897.2617  stock 1 number: 2427  stock 2 number: 76  open cash4490.168
# ..........
# 2004-09-03 00:00:00
# Total portfolio value: 12900.1157  stock 1 number: 2428  stock 2 number: 76  open cash4487.8949
# ..........
# 2004-09-07 00:00:00
# Total portfolio value: 12958.2314  stock 1 number: 2429  stock 2 number: 76  open cash4485.6513
# ..........
# 2004-09-08 00:00:00
# Total portfolio value: 12958.2844  stock 1 number: 2430  stock 2 number: 76  open cash4483.3844
# ..........
# 2004-09-09 00:00:00
# Total portfolio value: 13005.8349  stock 1 number: 2431  stock 2 number: 76  open cash4481.0984
# ..........
# 2004-09-10 00:00:00
# Total portfolio value: 12938.1341  stock 1 number: 2432  stock 2 number: 76  open cash4478.7869
# ..........
# 2004-09-13 00:00:00
# Total portfolio value: 13036.7936  stock 1 number: 2433  stock 2 number: 76  open cash4476.5023
# ..........
# 2004-09-14 00:00:00
# Total portfolio value: 13031.7364  stock 1 number: 2434  stock 2 number: 76  open cash4474.2062
# ..........
# 2004-09-15 00:00:00
# Total portfolio value: 13198.9444  stock 1 number: 2435  stock 2 number: 76  open cash4471.9459
# ..........
# 2004-09-16 00:00:00
# Total portfolio value: 13185.886  stock 1 number: 2436  stock 2 number: 76  open cash4469.6728
# ..........
# 2004-09-17 00:00:00
# Total portfolio value: 13426.3554  stock 1 number: 2437  stock 2 number: 76  open cash4467.4191
# ..........
# 2004-09-20 00:00:00
# Total portfolio value: 13481.4256  stock 1 number: 2438  stock 2 number: 76  open cash4465.0792
# ..........
# 2004-09-21 00:00:00
# Total portfolio value: 13656.4624  stock 1 number: 2439  stock 2 number: 76  open cash4462.7164
# ..........
# 2004-09-22 00:00:00
# Total portfolio value: 13692.0824  stock 1 number: 2440  stock 2 number: 76  open cash4460.3024
# ..........
# 2004-09-23 00:00:00
# Total portfolio value: 13388.7508  stock 1 number: 2441  stock 2 number: 76  open cash4457.8629
# ..........
# 2004-09-24 00:00:00
# Total portfolio value: 13481.3968  stock 1 number: 2442  stock 2 number: 76  open cash4455.491
# ..........
# 2004-09-27 00:00:00
# Total portfolio value: 13328.6599  stock 1 number: 2443  stock 2 number: 76  open cash4453.0961
# ..........
# 2004-09-28 00:00:00
# Total portfolio value: 13379.7823  stock 1 number: 2444  stock 2 number: 76  open cash4450.7295
# ..........
# 2004-09-29 00:00:00
# Total portfolio value: 13382.9883  stock 1 number: 2445  stock 2 number: 76  open cash4448.3283
# ..........
# 2004-09-30 00:00:00
# Total portfolio value: 13635.8515  stock 1 number: 2446  stock 2 number: 76  open cash4445.9003
# ..........
# 2004-10-01 00:00:00
# Total portfolio value: 13707.1334  stock 1 number: 2447  stock 2 number: 76  open cash4443.4031
# ..........
# 2004-10-04 00:00:00
# Total portfolio value: 13720.9958  stock 1 number: 2448  stock 2 number: 76  open cash4440.8982
# ..........
# 2004-10-05 00:00:00
# Total portfolio value: 13588.8105  stock 1 number: 2449  stock 2 number: 76  open cash4438.3895
# ..........
# 2004-10-06 00:00:00
# Total portfolio value: 13728.4305  stock 1 number: 2450  stock 2 number: 76  open cash4435.9205
# ..........
# 2004-10-07 00:00:00
# Total portfolio value: 13944.622  stock 1 number: 2451  stock 2 number: 76  open cash4433.3911
# ..........
# 2004-10-08 00:00:00
# Total portfolio value: 13749.7184  stock 1 number: 2452  stock 2 number: 76  open cash4430.7952
# ..........
# 2004-10-11 00:00:00
# Total portfolio value: 13549.0621  stock 1 number: 2453  stock 2 number: 76  open cash4428.2636
# ..........
# 2004-10-12 00:00:00
# Total portfolio value: 13480.9345  stock 1 number: 2454  stock 2 number: 76  open cash4425.7791
# ..........
# 2004-10-13 00:00:00
# Total portfolio value: 13674.3875  stock 1 number: 2455  stock 2 number: 76  open cash4423.314
# ..........
# 2004-10-14 00:00:00
# Total portfolio value: 14187.5187  stock 1 number: 2456  stock 2 number: 76  open cash4420.8283
# ..........
# 2004-10-15 00:00:00
# Total portfolio value: 14465.0619  stock 1 number: 2457  stock 2 number: 76  open cash4418.0724
# ..........
# 2004-10-18 00:00:00
# Total portfolio value: 14372.3023  stock 1 number: 2458  stock 2 number: 76  open cash4415.1989
# ..........
# 2004-10-19 00:00:00
# Total portfolio value: 15006.0457  stock 1 number: 2459  stock 2 number: 76  open cash4412.3316
# ..........
# 2004-10-20 00:00:00
# Total portfolio value: 14724.9717  stock 1 number: 2460  stock 2 number: 76  open cash4409.2517
# ..........
# 2004-10-21 00:00:00
# Total portfolio value: 14908.184  stock 1 number: 2461  stock 2 number: 76  open cash4406.2357
# ..........
# 2004-10-22 00:00:00
# Total portfolio value: 14628.0754  stock 1 number: 2462  stock 2 number: 76  open cash4403.1854
# ..........
# 2004-10-25 00:00:00
# Total portfolio value: 14434.669  stock 1 number: 2463  stock 2 number: 76  open cash4400.1504
# ..........
# 2004-10-26 00:00:00
# Total portfolio value: 14480.6242  stock 1 number: 2464  stock 2 number: 76  open cash4397.1282
# ..........
# 2004-10-27 00:00:00
# Total portfolio value: 14629.9232  stock 1 number: 2465  stock 2 number: 76  open cash4394.0892
# ..........
# 2004-10-28 00:00:00
# Total portfolio value: 14885.4  stock 1 number: 2466  stock 2 number: 76  open cash4390.9736
# ..........
# 2004-10-29 00:00:00
# Total portfolio value: 15187.8463  stock 1 number: 2467  stock 2 number: 76  open cash4387.7732
# ..........
# 2004-11-01 00:00:00
# Total portfolio value: 15282.8563  stock 1 number: 2468  stock 2 number: 76  open cash4384.4539
# ..........
# 2004-11-02 00:00:00
# Total portfolio value: 15363.4975  stock 1 number: 2469  stock 2 number: 76  open cash4381.0921
# ..........
# 2004-11-03 00:00:00
# Total portfolio value: 15815.8685  stock 1 number: 2470  stock 2 number: 76  open cash4377.7355
# ..........
# 2004-11-04 00:00:00
# Total portfolio value: 15797.2678  stock 1 number: 2471  stock 2 number: 76  open cash4374.2496
# ..........
# 2004-11-05 00:00:00
# Total portfolio value: 15899.907  stock 1 number: 2472  stock 2 number: 76  open cash4370.7254
# ..........
# 2004-11-08 00:00:00
# Total portfolio value: 15755.8635  stock 1 number: 2473  stock 2 number: 76  open cash4367.2101
# ..........
# 2004-11-09 00:00:00
# Total portfolio value: 15757.7039  stock 1 number: 2474  stock 2 number: 76  open cash4363.7343
# ..........
# 2004-11-10 00:00:00
# Total portfolio value: 15801.4039  stock 1 number: 2475  stock 2 number: 76  open cash4360.2639
# ..........
# 2004-11-11 00:00:00
# Total portfolio value: 15965.1879  stock 1 number: 2476  stock 2 number: 76  open cash4356.8087
# ..........
# 2004-11-12 00:00:00
# Total portfolio value: 16044.5881  stock 1 number: 2477  stock 2 number: 76  open cash4353.2895
# ..........
# 2004-11-15 00:00:00
# Total portfolio value: 16154.7703  stock 1 number: 2478  stock 2 number: 76  open cash4349.7677
# ..........
# 2004-11-16 00:00:00
# Total portfolio value: 16180.069  stock 1 number: 2479  stock 2 number: 76  open cash4346.241
# ..........
# 2004-11-17 00:00:00
# Total portfolio value: 16175.693  stock 1 number: 2480  stock 2 number: 76  open cash4342.709
# ..........
# 2004-11-18 00:00:00
# Total portfolio value: 15984.8446  stock 1 number: 2481  stock 2 number: 76  open cash4339.1757
# ..........
# 2004-11-19 00:00:00
# Total portfolio value: 16130.8858  stock 1 number: 2482  stock 2 number: 76  open cash4335.6988
# ..........
# 2004-11-22 00:00:00
# Total portfolio value: 16472.8586  stock 1 number: 2483  stock 2 number: 76  open cash4332.1453
# ..........
# 2004-11-23 00:00:00
# Total portfolio value: 17135.8054  stock 1 number: 2484  stock 2 number: 76  open cash4328.4302
# ..........
# 2004-11-24 00:00:00
# Total portfolio value: 17092.8214  stock 1 number: 2485  stock 2 number: 76  open cash4324.4424
# ..........
# 2004-11-26 00:00:00
# Total portfolio value: 17681.3712  stock 1 number: 2486  stock 2 number: 76  open cash4320.493
# ..........
# 2004-11-29 00:00:00
# Total portfolio value: 18312.9501  stock 1 number: 2487  stock 2 number: 76  open cash4316.3093
# ..........
# 2004-11-30 00:00:00
# Total portfolio value: 18233.9973  stock 1 number: 2488  stock 2 number: 76  open cash4311.8909
# ..........
# 2004-12-01 00:00:00
# Total portfolio value: 18031.767  stock 1 number: 2489  stock 2 number: 76  open cash4307.4856
# ..........
# 2004-12-02 00:00:00
# Total portfolio value: 17858.244  stock 1 number: 2490  stock 2 number: 76  open cash4303.193
# ..........
# 2004-12-03 00:00:00
# Total portfolio value: 17663.6149  stock 1 number: 2491  stock 2 number: 76  open cash4298.9591
# ..........
# 2004-12-06 00:00:00
# Total portfolio value: 17564.8981  stock 1 number: 2492  stock 2 number: 76  open cash4294.8253
# ..........
# 2004-12-07 00:00:00
# Total portfolio value: 17814.8565  stock 1 number: 2493  stock 2 number: 76  open cash4290.7119
# ..........
# 2004-12-08 00:00:00
# Total portfolio value: 17272.3251  stock 1 number: 2494  stock 2 number: 76  open cash4286.4897
# ..........
# 2004-12-09 00:00:00
# Total portfolio value: 17227.2576  stock 1 number: 2495  stock 2 number: 76  open cash4282.4506
# ..........
# 2004-12-10 00:00:00
# Total portfolio value: 17689.7136  stock 1 number: 2496  stock 2 number: 76  open cash4278.432
# ..........
# 2004-12-13 00:00:00
# Total portfolio value: 17772.6992  stock 1 number: 2497  stock 2 number: 76  open cash4274.2674
# ..........
# 2004-12-14 00:00:00
# Total portfolio value: 17769.8426  stock 1 number: 2498  stock 2 number: 76  open cash4270.058
# ..........
# 2004-12-15 00:00:00
# Total portfolio value: 17786.0216  stock 1 number: 2499  stock 2 number: 76  open cash4265.8753
# ..........
# 2004-12-16 00:00:00
# Total portfolio value: 17972.3216  stock 1 number: 2500  stock 2 number: 76  open cash4261.6916
# ..........
# 2004-12-17 00:00:00
# Total portfolio value: 18025.6739  stock 1 number: 2501  stock 2 number: 76  open cash4257.4501
# ..........
# 2004-12-20 00:00:00
# Total portfolio value: 17791.4173  stock 1 number: 2502  stock 2 number: 76  open cash4253.1663
# ..........
# 2004-12-21 00:00:00
# Total portfolio value: 17391.5655  stock 1 number: 2503  stock 2 number: 76  open cash4248.9658
# ..........
# 2004-12-22 00:00:00
# Total portfolio value: 17465.6439  stock 1 number: 2504  stock 2 number: 76  open cash4244.8959
# ..........
# 2004-12-23 00:00:00
# Total portfolio value: 17465.6489  stock 1 number: 2505  stock 2 number: 76  open cash4240.7864
# ..........
# 2004-12-27 00:00:00
# Total portfolio value: 17631.5953  stock 1 number: 2506  stock 2 number: 76  open cash4236.7039
# ..........
# 2004-12-28 00:00:00
# Total portfolio value: 17735.1085  stock 1 number: 2507  stock 2 number: 76  open cash4232.557
# ..........
# 2004-12-29 00:00:00
# Total portfolio value: 17897.8169  stock 1 number: 2508  stock 2 number: 76  open cash4228.5025
# ..........
# 2004-12-30 00:00:00
# Total portfolio value: 18059.6228  stock 1 number: 2509  stock 2 number: 76  open cash4224.4107
# ..........
# 2004-12-31 00:00:00
# Total portfolio value: 18086.0198  stock 1 number: 2510  stock 2 number: 76  open cash4220.2638
# ..........
# 2005-01-03 00:00:00
# Total portfolio value: 18064.0401  stock 1 number: 2511  stock 2 number: 76  open cash4216.1082
# ..........
# 2005-01-04 00:00:00
# Total portfolio value: 17706.3153  stock 1 number: 2512  stock 2 number: 76  open cash4211.9553
# ..........
# 2005-01-05 00:00:00
# Total portfolio value: 17655.4148  stock 1 number: 2513  stock 2 number: 76  open cash4207.8728
# ..........
# 2005-01-06 00:00:00
# Total portfolio value: 17815.2162  stock 1 number: 2514  stock 2 number: 76  open cash4203.7788
# ..........
# 2005-01-07 00:00:00
# Total portfolio value: 17812.3987  stock 1 number: 2515  stock 2 number: 76  open cash4199.6297
# ..........
# 2005-01-10 00:00:00
# Total portfolio value: 18637.6863  stock 1 number: 2516  stock 2 number: 76  open cash4195.4651
# ..........
# 2005-01-11 00:00:00
# Total portfolio value: 18335.4209  stock 1 number: 2517  stock 2 number: 76  open cash4190.9894
# ..........
# 2005-01-12 00:00:00
# Total portfolio value: 17902.4169  stock 1 number: 2518  stock 2 number: 76  open cash4186.6199
# ..........
# 2005-01-13 00:00:00
# Total portfolio value: 19321.4617  stock 1 number: 2519  stock 2 number: 76  open cash4182.4284
# ..........
# 2005-01-14 00:00:00
# Total portfolio value: 18762.4217  stock 1 number: 2520  stock 2 number: 76  open cash4177.6977
# ..........
# 2005-01-18 00:00:00
# Total portfolio value: 18821.6716  stock 1 number: 2521  stock 2 number: 76  open cash4173.2
# ..........
# 2005-01-19 00:00:00
# Total portfolio value: 18941.7936  stock 1 number: 2522  stock 2 number: 76  open cash4168.7204
# ..........
# 2005-01-20 00:00:00
# Total portfolio value: 18587.2413  stock 1 number: 2523  stock 2 number: 76  open cash4164.1998
# ..........
# 2005-01-21 00:00:00
# Total portfolio value: 18855.5789  stock 1 number: 2524  stock 2 number: 76  open cash4159.7393
# ..........
# 2005-01-24 00:00:00
# Total portfolio value: 18792.8264  stock 1 number: 2525  stock 2 number: 76  open cash4155.1764
# ..........
# 2005-01-25 00:00:00
# Total portfolio value: 18785.3492  stock 1 number: 2526  stock 2 number: 76  open cash4150.6224
# ..........
# 2005-01-26 00:00:00
# Total portfolio value: 19040.9505  stock 1 number: 2527  stock 2 number: 76  open cash4146.0506
# ..........
# 2005-01-27 00:00:00
# Total portfolio value: 18956.2609  stock 1 number: 2528  stock 2 number: 76  open cash4141.3969
# ..........
# 2005-01-28 00:00:00
# Total portfolio value: 19085.3387  stock 1 number: 2529  stock 2 number: 76  open cash4136.7764
# ..........
# 2005-01-31 00:00:00
# Total portfolio value: 19481.0827  stock 1 number: 2530  stock 2 number: 76  open cash4132.1277
# ..........
# 2005-02-01 00:00:00
# Total portfolio value: 19881.0143  stock 1 number: 2531  stock 2 number: 76  open cash4127.3382
# ..........
# 2005-02-02 00:00:00
# Total portfolio value: 20043.5727  stock 1 number: 2532  stock 2 number: 76  open cash4122.4051
# ..........
# 2005-02-03 00:00:00
# Total portfolio value: 19621.4929  stock 1 number: 2533  stock 2 number: 76  open cash4117.4108
# ..........
# 2005-02-04 00:00:00
# Total portfolio value: 19476.5333  stock 1 number: 2534  stock 2 number: 76  open cash4112.3371
# ..........
# 2005-02-07 00:00:00
# Total portfolio value: 19647.6403  stock 1 number: 2535  stock 2 number: 76  open cash4107.3428
# ..........
# 2005-02-08 00:00:00
# Total portfolio value: 19662.6179  stock 1 number: 2536  stock 2 number: 76  open cash4102.2843
# ..........
# 2005-02-09 00:00:00
# Total portfolio value: 20062.852  stock 1 number: 2537  stock 2 number: 76  open cash4097.2142
# ..........
# 2005-02-10 00:00:00
# Total portfolio value: 19635.7626  stock 1 number: 2538  stock 2 number: 76  open cash4092.0148
# ..........
# 2005-02-11 00:00:00
# Total portfolio value: 19794.0239  stock 1 number: 2539  stock 2 number: 76  open cash4086.9717
# ..........
# 2005-02-14 00:00:00
# Total portfolio value: 20245.1319  stock 1 number: 2540  stock 2 number: 76  open cash4081.8519
# ..........
# 2005-02-15 00:00:00
# Total portfolio value: 20945.5453  stock 1 number: 2541  stock 2 number: 76  open cash4076.5539
# ..........
# 2005-02-16 00:00:00
# Total portfolio value: 21153.5381  stock 1 number: 2542  stock 2 number: 76  open cash4070.9985
# ..........
# 2005-02-17 00:00:00
# Total portfolio value: 21545.484  stock 1 number: 2543  stock 2 number: 76  open cash4065.3547
# ..........
# 2005-02-18 00:00:00
# Total portfolio value: 21061.4376  stock 1 number: 2544  stock 2 number: 76  open cash4059.5496
# ..........
# 2005-02-22 00:00:00
# Total portfolio value: 20799.9936  stock 1 number: 2545  stock 2 number: 76  open cash4053.9276
# ..........
# 2005-02-23 00:00:00
# Total portfolio value: 20846.5968  stock 1 number: 2546  stock 2 number: 76  open cash4048.3928
# ..........
# 2005-02-24 00:00:00
# Total portfolio value: 21002.6941  stock 1 number: 2547  stock 2 number: 76  open cash4042.8388
# ..........
# 2005-02-25 00:00:00
# Total portfolio value: 21301.1917  stock 1 number: 2548  stock 2 number: 76  open cash4037.1889
# ..........
# 2005-02-28 00:00:00
# Total portfolio value: 21249.9286  stock 1 number: 2549  stock 2 number: 76  open cash4031.4478
# ..........
# 2005-03-01 00:00:00
# Total portfolio value: 21412.7436  stock 1 number: 2550  stock 2 number: 76  open cash4025.7286
# ..........
# 2005-03-02 00:00:00
# Total portfolio value: 21151.8936  stock 1 number: 2551  stock 2 number: 76  open cash4019.9533
# ..........
# 2005-03-03 00:00:00
# Total portfolio value: 21223.9752  stock 1 number: 2552  stock 2 number: 76  open cash4014.288
# ..........
# 2005-03-04 00:00:00
# Total portfolio value: 20393.3073  stock 1 number: 2553  stock 2 number: 76  open cash4008.6019
# ..........
# 2005-03-07 00:00:00
# Total portfolio value: 20726.6043  stock 1 number: 2554  stock 2 number: 76  open cash4003.2501
# ..........
# 2005-03-08 00:00:00
# Total portfolio value: 20460.8083  stock 1 number: 2555  stock 2 number: 76  open cash3997.7678
# ..........
# 2005-03-09 00:00:00
# Total portfolio value: 19673.9003  stock 1 number: 2556  stock 2 number: 76  open cash3992.4047
# ..........
# 2005-03-10 00:00:00
# Total portfolio value: 19630.5803  stock 1 number: 2557  stock 2 number: 76  open cash3987.3346
# ..........
# 2005-03-11 00:00:00
# Total portfolio value: 19777.4793  stock 1 number: 2558  stock 2 number: 76  open cash3982.2645
# ..........
# 2005-03-14 00:00:00
# Total portfolio value: 19889.9349  stock 1 number: 2559  stock 2 number: 76  open cash3977.1239
# ..........
# 2005-03-15 00:00:00
# Total portfolio value: 19924.8389  stock 1 number: 2560  stock 2 number: 76  open cash3971.9349
# ..........
# 2005-03-16 00:00:00
# Total portfolio value: 20079.8304  stock 1 number: 2561  stock 2 number: 76  open cash3966.729
# ..........
# 2005-03-17 00:00:00
# Total portfolio value: 20149.4774  stock 1 number: 2562  stock 2 number: 76  open cash3961.4516
# ..........
# 2005-03-18 00:00:00
# Total portfolio value: 20753.4145  stock 1 number: 2563  stock 2 number: 76  open cash3956.1307
# ..........
# 2005-03-21 00:00:00
# Total portfolio value: 20773.8345  stock 1 number: 2564  stock 2 number: 76  open cash3950.5881
# ..........
# 2005-03-22 00:00:00
# Total portfolio value: 20871.7605  stock 1 number: 2565  stock 2 number: 76  open cash3945.0405
# ..........
# 2005-03-23 00:00:00
# Total portfolio value: 20414.1687  stock 1 number: 2566  stock 2 number: 76  open cash3939.4405
# ..........
# 2005-03-24 00:00:00
# Total portfolio value: 20598.8858  stock 1 number: 2567  stock 2 number: 76  open cash3933.9978
# ..........
# 2005-03-28 00:00:00
# Total portfolio value: 20496.7866  stock 1 number: 2568  stock 2 number: 76  open cash3928.4938
# ..........
# 2005-03-29 00:00:00
# Total portfolio value: 20450.6946  stock 1 number: 2569  stock 2 number: 76  open cash3923.0192
# ..........
# 2005-03-30 00:00:00
# Total portfolio value: 20284.2506  stock 1 number: 2570  stock 2 number: 76  open cash3917.5726
# ..........
# 2005-03-31 00:00:00
# Total portfolio value: 20507.3683  stock 1 number: 2571  stock 2 number: 76  open cash3912.1952
# ..........
# 2005-04-01 00:00:00
# Total portfolio value: 20391.3363  stock 1 number: 2572  stock 2 number: 76  open cash3906.7591
# ..........
# 2005-04-04 00:00:00
# Total portfolio value: 19923.9145  stock 1 number: 2573  stock 2 number: 76  open cash3901.369
# ..........
# 2005-04-05 00:00:00
# Total portfolio value: 20138.8007  stock 1 number: 2574  stock 2 number: 76  open cash3896.1455
# ..........
# 2005-04-06 00:00:00
# Total portfolio value: 20542.4982  stock 1 number: 2575  stock 2 number: 76  open cash3890.8707
# ..........
# 2005-04-07 00:00:00
# Total portfolio value: 20480.799  stock 1 number: 2576  stock 2 number: 76  open cash3885.4406
# ..........
# 2005-04-08 00:00:00
# Total portfolio value: 20916.3994  stock 1 number: 2577  stock 2 number: 76  open cash3880.0197
# ..........
# 2005-04-11 00:00:00
# Total portfolio value: 21105.377  stock 1 number: 2578  stock 2 number: 76  open cash3874.4336
# ..........
# 2005-04-12 00:00:00
# Total portfolio value: 20523.5022  stock 1 number: 2579  stock 2 number: 76  open cash3868.7683
# ..........
# 2005-04-13 00:00:00
# Total portfolio value: 20674.2442  stock 1 number: 2580  stock 2 number: 76  open cash3863.3242
# ..........
# 2005-04-14 00:00:00
# Total portfolio value: 19285.0349  stock 1 number: 2581  stock 2 number: 76  open cash3857.8202
# ..........
# 2005-04-15 00:00:00
# Total portfolio value: 18525.5803  stock 1 number: 2582  stock 2 number: 76  open cash3852.8515
# ..........
# 2005-04-18 00:00:00
# Total portfolio value: 17951.3544  stock 1 number: 2583  stock 2 number: 76  open cash3848.1631
# ..........
# 2005-04-19 00:00:00
# Total portfolio value: 18460.0984  stock 1 number: 2584  stock 2 number: 76  open cash3843.672
# ..........
# 2005-04-20 00:00:00
# Total portfolio value: 18825.8294  stock 1 number: 2585  stock 2 number: 76  open cash3838.9899
# ..........
# 2005-04-21 00:00:00
# Total portfolio value: 18428.5998  stock 1 number: 2586  stock 2 number: 76  open cash3834.1672
# ..........
# 2005-04-22 00:00:00
# Total portfolio value: 18576.6256  stock 1 number: 2587  stock 2 number: 76  open cash3829.5081
# ..........
# 2005-04-25 00:00:00
# Total portfolio value: 18437.1432  stock 1 number: 2588  stock 2 number: 76  open cash3824.7956
# ..........
# 2005-04-26 00:00:00
# Total portfolio value: 18534.2725  stock 1 number: 2589  stock 2 number: 76  open cash3820.1229
# ..........
# 2005-04-27 00:00:00
# Total portfolio value: 18027.7915  stock 1 number: 2590  stock 2 number: 76  open cash3815.4165
# ..........
# 2005-04-28 00:00:00
# Total portfolio value: 18260.1153  stock 1 number: 2591  stock 2 number: 76  open cash3810.832
# ..........
# 2005-04-29 00:00:00
# Total portfolio value: 18258.6321  stock 1 number: 2592  stock 2 number: 76  open cash3806.1857
# ..........
# 2005-05-02 00:00:00
# Total portfolio value: 18295.8736  stock 1 number: 2593  stock 2 number: 76  open cash3801.569
# ..........
# 2005-05-03 00:00:00
# Total portfolio value: 18393.0578  stock 1 number: 2594  stock 2 number: 76  open cash3796.9268
# ..........
# 2005-05-04 00:00:00
# Total portfolio value: 18368.0543  stock 1 number: 2595  stock 2 number: 76  open cash3792.2653
# ..........
# 2005-05-05 00:00:00
# Total portfolio value: 18737.4283  stock 1 number: 2596  stock 2 number: 76  open cash3787.6231
# ..........
# 2005-05-06 00:00:00
# Total portfolio value: 18680.932  stock 1 number: 2597  stock 2 number: 76  open cash3782.8594
# ..........
# 2005-05-09 00:00:00
# Total portfolio value: 18787.1202  stock 1 number: 2598  stock 2 number: 76  open cash3778.1236
# --------------------------------
# Total Profit: $0.00
# Total No. of days played: 499  out of overall days:  500
# Total portfolio value: 18787.1202  stock 1 number: 2599  stock 2 number: 76  open cash3773.3519
# --------------------------------

# %%
# Test Stock Prices and actions taken by agent Stock Plot
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %matplotlib inline

pd_bm=pd.DataFrame.from_records(Benchmark_Port_Value)
pd_bm[0]=pd.to_datetime(pd_bm[0], format='%Y/%m/%d')

x1 = np.array(pd_data1_test['Date'])
y1 = portfolio_value

x2=pd_bm[0]
y2=pd_bm[1]



plt.title("Portfolio Value vs Benchmark Over Test Data")
plt.xlabel("Days")
plt.ylabel("Portfolio Value in $")

plt.plot(x1,y1)
plt.plot_date(x2, y2, c = 'blue', marker='v', linestyle='-')


#plt.plot(x1, z, '-', color='black');
plt.plot(x1, y1, '-', color='green');



#plt.scatter(x1,Benchmark_Port_Value,marker='o')

plt.legend(('Trading Model', 'Benchmark'))

plt.show()
